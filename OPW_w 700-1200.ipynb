# %%
import torch
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
def OPW_w(x: torch.Tensor, y: torch.Tensor, a: torch.Tensor = None, b: torch.Tensor = None, std=1, verbose=0, lambda1=0.1, lambda2=10,
          tol=.5e-2, maxIter=20, p_norm='inf', metric='sqreuclidean'):
    assert y.size(1) == x.size(1), "The dimensions of instances in the input sequences must be the same!"
    N = x.size(0)
    M = y.size(0)
    col_x = torch.arange(1, N+1)/N
    col_x = col_x.view(N, 1)
    col_y = torch.arange(1, M+1)/M
    relative_pos = col_x-col_y

    l = torch.abs(relative_pos) / ((1/N**2 + 1/M**2)**0.5)
    P = torch.exp(-l**2/(2*std**2)) / (std*(2*np.pi)**0.5)

    S = lambda1 / (relative_pos**2 + 1)

    D = pdist2(x, y, metric=metric)

    K = P * torch.exp((S - D) / lambda2)

    if a is None:
        a = torch.ones(N, 1) / N

    if b is None:
        b = torch.ones(M, 1) / M

    ainvK = K / a   # [N, M]

    iter = 0
    u = torch.ones(N, 1) / N
    while iter < maxIter:
        u = 1. / torch.matmul(ainvK, (b / (torch.matmul(K.T, u))))
        
        iter += 1
        if iter % 20 == 1 or iter == maxIter:
            v = b / torch.matmul(K.T, u)    # [M, 1]
            u = 1 / torch.matmul(ainvK, v)  # [N, 1]

            criterion = torch.sum(torch.abs(v * torch.matmul(K.T, u) - b), dim=0)
            criterion = criterion.norm(p=float(p_norm))
            if abs(criterion) < tol:
                break

            iter += 1
            if verbose > 0:
                print(f"Iteration : {iter}, Criterion: {criterion}")

    U = K * D   # [N, M]
    
    dist = torch.sum(u * torch.matmul(U, v), dim=0)
    T = v.T * (u * K)
 
    return dist, T

# %%
def pdist2(X, Y, metric='sqreuclidean'):
    if metric.lower() == 'sqreuclidean':
        return distEucSqr(X, Y)
    elif metric.lower() == 'euclidean':
        return torch.sqrt(distEucSqr(X, Y))
    elif metric.lower() == 'L1':
        return distL1(X, Y)
    elif metric.lower() == 'cosine':
        return distCosine(X, Y)
    elif metric.lower() == 'emd':
        return distEmd(X, Y)
    elif metric.lower() == 'chisqr':
        return distChiSqr(X, Y)
    else:
        raise NotImplementedError(f'pdist - unknown metric: {metric}')


def distL1(x: torch.Tensor, y: torch.Tensor):
    return torch.abs(x.unsqueeze(1) - y).sum(dim=-1)


def distCosine(x: torch.Tensor, y: torch.Tensor, eps=1e-8):
    assert x.dtype == torch.float or y.dtype == torch.float, "Inputs must be of type float"
    cos = torch.nn.CosineSimilarity(dim=-1, eps=eps)
    return 1 - cos(x.unsqueeze(1), y)


def distEmd(x: torch.Tensor, y: torch.Tensor):
    x_cdf = torch.cumsum(x, dim=-1)
    y_cdf = torch.cumsum(y, dim=-1)

    return torch.abs(x_cdf.unsqueeze(1) - y_cdf).sum(dim=-1)


def distEucSqr(x: torch.Tensor, y: torch.Tensor):
    return torch.cdist(x, y, p=2)**2


def distChiSqr(x: torch.Tensor, y: torch.Tensor, eps=1e-10):
    a = x.unsqueeze(1) + y
    b = x.unsqueeze(1) - y
    return (b**2 / (a + eps)).sum(dim=-1) / 2

# %%
def get_utterances(path):
  X = []
  utterances = []
  count = 0
  with open(path, 'r') as f:
      length_X = len([line for line in f.read().splitlines()])
  with open(path, 'r') as f:
      for line in f.read().splitlines():
          count += 1
          frame = [-abs(float(i)) if i.startswith('-') else abs(float(i)) for i in line.split()]
          if len(frame) > 0:
            utterances.append(frame)
            if count == length_X:
              X.append(utterances)
          else:
            if len(utterances) > 0:
              X.append(utterances)
              utterances = []
          
  return X

# %%
X_train = get_utterances(path="/content/Train_Arabic_Digit.txt")
X_test = get_utterances(path="/content/Test_Arabic_Digit.txt")
print(f"Number of training sample: {len(X_train)}")
print(f"Number of testing sample: {len(X_test)}")
# Out:
# Number of training sample: 6600
# Number of testing sample: 2200

# %%
import torch
import numpy as np
import json 

n_class = torch.Tensor(torch.arange(0, 10)).view(10, 1)
y_train = n_class.expand_as(torch.empty((10, 660))).contiguous().view(6600)
y_test = n_class.expand_as(torch.empty((10, 220))).contiguous().view(2200)

# %%
with open('fe.json', 'w') as f:
    json.dump(3, f)

# %%
W_dist = []
for idx_X, X in enumerate(X_test):
    if idx_X < 1200 and idx_X >= 700:
      print(f'Calculating all distances of sample {idx_X+1}')
      W_X = []
      for idx_Y, Y in enumerate(X_train):
          dist, minT = OPW_w(torch.Tensor(X), torch.Tensor(Y), verbose=0, lambda1=0.1, lambda2=10)
          W_X.append(dist.item())
      W_dist.append(W_X)

with open('/content/distances700-1200.json', 'w') as f:
    json.dump(W_dist, f)
# Out:
# Calculating all distances of sample 701
# Calculating all distances of sample 702
# Calculating all distances of sample 703
# Calculating all distances of sample 704
# Calculating all distances of sample 705
# Calculating all distances of sample 706
# Calculating all distances of sample 707
# Calculating all distances of sample 708
# Calculating all distances of sample 709
# Calculating all distances of sample 710
# Calculating all distances of sample 711
# Calculating all distances of sample 712
# Calculating all distances of sample 713
# Calculating all distances of sample 714
# Calculating all distances of sample 715
# Calculating all distances of sample 716
# Calculating all distances of sample 717
# Calculating all distances of sample 718
# Calculating all distances of sample 719
# Calculating all distances of sample 720
# Calculating all distances of sample 721
# Calculating all distances of sample 722
# Calculating all distances of sample 723
# Calculating all distances of sample 724
# Calculating all distances of sample 725
# Calculating all distances of sample 726
# Calculating all distances of sample 727
# Calculating all distances of sample 728
# Calculating all distances of sample 729
# Calculating all distances of sample 730
# Calculating all distances of sample 731
# Calculating all distances of sample 732
# Calculating all distances of sample 733
# Calculating all distances of sample 734
# Calculating all distances of sample 735
# Calculating all distances of sample 736
# Calculating all distances of sample 737
# Calculating all distances of sample 738
# Calculating all distances of sample 739
# Calculating all distances of sample 740
# Calculating all distances of sample 741
# Calculating all distances of sample 742
# Calculating all distances of sample 743
# Calculating all distances of sample 744
# Calculating all distances of sample 745
# Calculating all distances of sample 746
# Calculating all distances of sample 747
# Calculating all distances of sample 748
# Calculating all distances of sample 749
# Calculating all distances of sample 750
# Calculating all distances of sample 751
# Calculating all distances of sample 752
# Calculating all distances of sample 753
# Calculating all distances of sample 754
# Calculating all distances of sample 755
# Calculating all distances of sample 756
# Calculating all distances of sample 757
# Calculating all distances of sample 758
# Calculating all distances of sample 759
# Calculating all distances of sample 760
# Calculating all distances of sample 761
# Calculating all distances of sample 762
# Calculating all distances of sample 763
# Calculating all distances of sample 764
# Calculating all distances of sample 765
# Calculating all distances of sample 766
# Calculating all distances of sample 767
# Calculating all distances of sample 768
# Calculating all distances of sample 769
# Calculating all distances of sample 770
# Calculating all distances of sample 771
# Calculating all distances of sample 772
# Calculating all distances of sample 773
# Calculating all distances of sample 774
# Calculating all distances of sample 775
# Calculating all distances of sample 776
# Calculating all distances of sample 777
# Calculating all distances of sample 778
# Calculating all distances of sample 779
# Calculating all distances of sample 780
# Calculating all distances of sample 781
# Calculating all distances of sample 782
# Calculating all distances of sample 783
# Calculating all distances of sample 784
# Calculating all distances of sample 785
# Calculating all distances of sample 786
# Calculating all distances of sample 787
# Calculating all distances of sample 788
# Calculating all distances of sample 789
# Calculating all distances of sample 790
# Calculating all distances of sample 791
# Calculating all distances of sample 792
# Calculating all distances of sample 793
# Calculating all distances of sample 794
# Calculating all distances of sample 795
# Calculating all distances of sample 796
# Calculating all distances of sample 797
# Calculating all distances of sample 798
# Calculating all distances of sample 799
# Calculating all distances of sample 800
# Calculating all distances of sample 801
# Calculating all distances of sample 802
# Calculating all distances of sample 803
# Calculating all distances of sample 804
# Calculating all distances of sample 805
# Calculating all distances of sample 806
# Calculating all distances of sample 807
# Calculating all distances of sample 808
# Calculating all distances of sample 809
# Calculating all distances of sample 810
# Calculating all distances of sample 811
# Calculating all distances of sample 812
# Calculating all distances of sample 813
# Calculating all distances of sample 814
# Calculating all distances of sample 815
# Calculating all distances of sample 816
# Calculating all distances of sample 817
# Calculating all distances of sample 818
# Calculating all distances of sample 819
# Calculating all distances of sample 820
# Calculating all distances of sample 821
# Calculating all distances of sample 822
# Calculating all distances of sample 823
# Calculating all distances of sample 824
# Calculating all distances of sample 825
# Calculating all distances of sample 826
# Calculating all distances of sample 827
# Calculating all distances of sample 828
# Calculating all distances of sample 829
# Calculating all distances of sample 830
# Calculating all distances of sample 831
# Calculating all distances of sample 832
# Calculating all distances of sample 833
# Calculating all distances of sample 834
# Calculating all distances of sample 835
# Calculating all distances of sample 836
# Calculating all distances of sample 837
# Calculating all distances of sample 838
# Calculating all distances of sample 839
# Calculating all distances of sample 840
# Calculating all distances of sample 841
# Calculating all distances of sample 842
# Calculating all distances of sample 843
# Calculating all distances of sample 844
# Calculating all distances of sample 845
# Calculating all distances of sample 846
# Calculating all distances of sample 847
# Calculating all distances of sample 848
# Calculating all distances of sample 849
# Calculating all distances of sample 850
# Calculating all distances of sample 851
# Calculating all distances of sample 852
# Calculating all distances of sample 853
# Calculating all distances of sample 854
# Calculating all distances of sample 855
# Calculating all distances of sample 856
# Calculating all distances of sample 857
# Calculating all distances of sample 858
# Calculating all distances of sample 859
# Calculating all distances of sample 860
# Calculating all distances of sample 861
# Calculating all distances of sample 862
# Calculating all distances of sample 863
# Calculating all distances of sample 864
# Calculating all distances of sample 865
# Calculating all distances of sample 866
# Calculating all distances of sample 867
# Calculating all distances of sample 868
# Calculating all distances of sample 869
# Calculating all distances of sample 870
# Calculating all distances of sample 871
# Calculating all distances of sample 872
# Calculating all distances of sample 873
# Calculating all distances of sample 874
# Calculating all distances of sample 875
# Calculating all distances of sample 876
# Calculating all distances of sample 877
# Calculating all distances of sample 878
# Calculating all distances of sample 879
# Calculating all distances of sample 880
# Calculating all distances of sample 881
# Calculating all distances of sample 882
# Calculating all distances of sample 883
# Calculating all distances of sample 884
# Calculating all distances of sample 885
# Calculating all distances of sample 886
# Calculating all distances of sample 887
# Calculating all distances of sample 888
# Calculating all distances of sample 889
# Calculating all distances of sample 890
# Calculating all distances of sample 891
# Calculating all distances of sample 892
# Calculating all distances of sample 893
# Calculating all distances of sample 894
# Calculating all distances of sample 895
# Calculating all distances of sample 896
# Calculating all distances of sample 897
# Calculating all distances of sample 898
# Calculating all distances of sample 899
# Calculating all distances of sample 900
# Calculating all distances of sample 901
# Calculating all distances of sample 902
# Calculating all distances of sample 903
# Calculating all distances of sample 904
# Calculating all distances of sample 905
# Calculating all distances of sample 906
# Calculating all distances of sample 907
# Calculating all distances of sample 908
# Calculating all distances of sample 909
# Calculating all distances of sample 910
# Calculating all distances of sample 911
# Calculating all distances of sample 912
# Calculating all distances of sample 913
# Calculating all distances of sample 914
# Calculating all distances of sample 915
# Calculating all distances of sample 916
# Calculating all distances of sample 917
# Calculating all distances of sample 918
# Calculating all distances of sample 919
# Calculating all distances of sample 920
# Calculating all distances of sample 921
# Calculating all distances of sample 922
# Calculating all distances of sample 923
# Calculating all distances of sample 924
# Calculating all distances of sample 925
# Calculating all distances of sample 926
# Calculating all distances of sample 927
# Calculating all distances of sample 928
# Calculating all distances of sample 929
# Calculating all distances of sample 930
# Calculating all distances of sample 931
# Calculating all distances of sample 932
# Calculating all distances of sample 933
# Calculating all distances of sample 934
# Calculating all distances of sample 935
# Calculating all distances of sample 936
# Calculating all distances of sample 937
# Calculating all distances of sample 938
# Calculating all distances of sample 939
# Calculating all distances of sample 940
# Calculating all distances of sample 941
# Calculating all distances of sample 942
# Calculating all distances of sample 943
# Calculating all distances of sample 944
# Calculating all distances of sample 945
# Calculating all distances of sample 946
# Calculating all distances of sample 947
# Calculating all distances of sample 948
# Calculating all distances of sample 949
# Calculating all distances of sample 950
# Calculating all distances of sample 951
# Calculating all distances of sample 952
# Calculating all distances of sample 953
# Calculating all distances of sample 954
# Calculating all distances of sample 955
# Calculating all distances of sample 956
# Calculating all distances of sample 957
# Calculating all distances of sample 958
# Calculating all distances of sample 959
# Calculating all distances of sample 960
# Calculating all distances of sample 961
# Calculating all distances of sample 962
# Calculating all distances of sample 963
# Calculating all distances of sample 964
# Calculating all distances of sample 965
# Calculating all distances of sample 966
# Calculating all distances of sample 967
# Calculating all distances of sample 968
# Calculating all distances of sample 969
# Calculating all distances of sample 970
# Calculating all distances of sample 971
# Calculating all distances of sample 972
# Calculating all distances of sample 973
# Calculating all distances of sample 974
# Calculating all distances of sample 975
# Calculating all distances of sample 976
# Calculating all distances of sample 977
# Calculating all distances of sample 978
# Calculating all distances of sample 979
# Calculating all distances of sample 980
# Calculating all distances of sample 981
# Calculating all distances of sample 982
# Calculating all distances of sample 983
# Calculating all distances of sample 984
# Calculating all distances of sample 985
# Calculating all distances of sample 986
# Calculating all distances of sample 987
# Calculating all distances of sample 988
# Calculating all distances of sample 989
# Calculating all distances of sample 990
# Calculating all distances of sample 991
# Calculating all distances of sample 992
# Calculating all distances of sample 993
# Calculating all distances of sample 994
# Calculating all distances of sample 995
# Calculating all distances of sample 996
# Calculating all distances of sample 997
# Calculating all distances of sample 998
# Calculating all distances of sample 999
# Calculating all distances of sample 1000
# Calculating all distances of sample 1001
# Calculating all distances of sample 1002
# Calculating all distances of sample 1003
# Calculating all distances of sample 1004
# Calculating all distances of sample 1005
# Calculating all distances of sample 1006
# Calculating all distances of sample 1007
# Calculating all distances of sample 1008
# Calculating all distances of sample 1009
# Calculating all distances of sample 1010
# Calculating all distances of sample 1011
# Calculating all distances of sample 1012
# Calculating all distances of sample 1013
# Calculating all distances of sample 1014
# Calculating all distances of sample 1015
# Calculating all distances of sample 1016
# Calculating all distances of sample 1017
# Calculating all distances of sample 1018
# Calculating all distances of sample 1019
# Calculating all distances of sample 1020
# Calculating all distances of sample 1021
# Calculating all distances of sample 1022
# Calculating all distances of sample 1023
# Calculating all distances of sample 1024
# Calculating all distances of sample 1025
# Calculating all distances of sample 1026
# Calculating all distances of sample 1027
# Calculating all distances of sample 1028
# Calculating all distances of sample 1029
# Calculating all distances of sample 1030
# Calculating all distances of sample 1031
# Calculating all distances of sample 1032
# Calculating all distances of sample 1033
# Calculating all distances of sample 1034
# Calculating all distances of sample 1035
# Calculating all distances of sample 1036
# Calculating all distances of sample 1037
# Calculating all distances of sample 1038
# Calculating all distances of sample 1039
# Calculating all distances of sample 1040
# Calculating all distances of sample 1041
# Calculating all distances of sample 1042
# Calculating all distances of sample 1043
# Calculating all distances of sample 1044
# Calculating all distances of sample 1045
# Calculating all distances of sample 1046
# Calculating all distances of sample 1047
# Calculating all distances of sample 1048
# Calculating all distances of sample 1049
# Calculating all distances of sample 1050
# Calculating all distances of sample 1051
# Calculating all distances of sample 1052
# Calculating all distances of sample 1053
# Calculating all distances of sample 1054
# Calculating all distances of sample 1055
# Calculating all distances of sample 1056
# Calculating all distances of sample 1057
# Calculating all distances of sample 1058
# Calculating all distances of sample 1059
# Calculating all distances of sample 1060
# Calculating all distances of sample 1061
# Calculating all distances of sample 1062
# Calculating all distances of sample 1063
# Calculating all distances of sample 1064
# Calculating all distances of sample 1065
# Calculating all distances of sample 1066
# Calculating all distances of sample 1067
# Calculating all distances of sample 1068
# Calculating all distances of sample 1069
# Calculating all distances of sample 1070
# Calculating all distances of sample 1071
# Calculating all distances of sample 1072
# Calculating all distances of sample 1073
# Calculating all distances of sample 1074
# Calculating all distances of sample 1075
# Calculating all distances of sample 1076
# Calculating all distances of sample 1077
# Calculating all distances of sample 1078
# Calculating all distances of sample 1079
# Calculating all distances of sample 1080
# Calculating all distances of sample 1081
# Calculating all distances of sample 1082
# Calculating all distances of sample 1083
# Calculating all distances of sample 1084
# Calculating all distances of sample 1085
# Calculating all distances of sample 1086
# Calculating all distances of sample 1087
# Calculating all distances of sample 1088
# Calculating all distances of sample 1089
# Calculating all distances of sample 1090
# Calculating all distances of sample 1091
# Calculating all distances of sample 1092
# Calculating all distances of sample 1093
# Calculating all distances of sample 1094
# Calculating all distances of sample 1095
# Calculating all distances of sample 1096
# Calculating all distances of sample 1097
# Calculating all distances of sample 1098
# Calculating all distances of sample 1099
# Calculating all distances of sample 1100
# Calculating all distances of sample 1101
# Calculating all distances of sample 1102
# Calculating all distances of sample 1103
# Calculating all distances of sample 1104
# Calculating all distances of sample 1105
# Calculating all distances of sample 1106
# Calculating all distances of sample 1107
# Calculating all distances of sample 1108
# Calculating all distances of sample 1109
# Calculating all distances of sample 1110
# Calculating all distances of sample 1111
# Calculating all distances of sample 1112
# Calculating all distances of sample 1113
# Calculating all distances of sample 1114
# Calculating all distances of sample 1115
# Calculating all distances of sample 1116
# Calculating all distances of sample 1117
# Calculating all distances of sample 1118
# Calculating all distances of sample 1119
# Calculating all distances of sample 1120
# Calculating all distances of sample 1121
# Calculating all distances of sample 1122
# Calculating all distances of sample 1123
# Calculating all distances of sample 1124
# Calculating all distances of sample 1125
# Calculating all distances of sample 1126
# Calculating all distances of sample 1127
# Calculating all distances of sample 1128
# Calculating all distances of sample 1129
# Calculating all distances of sample 1130
# Calculating all distances of sample 1131
# Calculating all distances of sample 1132
# Calculating all distances of sample 1133
# Calculating all distances of sample 1134
# Calculating all distances of sample 1135
# Calculating all distances of sample 1136
# Calculating all distances of sample 1137
# Calculating all distances of sample 1138
# Calculating all distances of sample 1139
# Calculating all distances of sample 1140
# Calculating all distances of sample 1141
# Calculating all distances of sample 1142
# Calculating all distances of sample 1143
# Calculating all distances of sample 1144
# Calculating all distances of sample 1145
# Calculating all distances of sample 1146
# Calculating all distances of sample 1147
# Calculating all distances of sample 1148
# Calculating all distances of sample 1149
# Calculating all distances of sample 1150
# Calculating all distances of sample 1151
# Calculating all distances of sample 1152
# Calculating all distances of sample 1153
# Calculating all distances of sample 1154
# Calculating all distances of sample 1155
# Calculating all distances of sample 1156
# Calculating all distances of sample 1157
# Calculating all distances of sample 1158
# Calculating all distances of sample 1159
# Calculating all distances of sample 1160
# Calculating all distances of sample 1161
# Calculating all distances of sample 1162
# Calculating all distances of sample 1163
# Calculating all distances of sample 1164
# Calculating all distances of sample 1165
# Calculating all distances of sample 1166
# Calculating all distances of sample 1167
# Calculating all distances of sample 1168
# Calculating all distances of sample 1169
# Calculating all distances of sample 1170
# Calculating all distances of sample 1171
# Calculating all distances of sample 1172
# Calculating all distances of sample 1173
# Calculating all distances of sample 1174
# Calculating all distances of sample 1175
# Calculating all distances of sample 1176
# Calculating all distances of sample 1177
# Calculating all distances of sample 1178
# Calculating all distances of sample 1179
# Calculating all distances of sample 1180
# Calculating all distances of sample 1181
# Calculating all distances of sample 1182
# Calculating all distances of sample 1183
# Calculating all distances of sample 1184
# Calculating all distances of sample 1185
# Calculating all distances of sample 1186
# Calculating all distances of sample 1187
# Calculating all distances of sample 1188
# Calculating all distances of sample 1189
# Calculating all distances of sample 1190
# Calculating all distances of sample 1191
# Calculating all distances of sample 1192
# Calculating all distances of sample 1193
# Calculating all distances of sample 1194
# Calculating all distances of sample 1195
# Calculating all distances of sample 1196
# Calculating all distances of sample 1197
# Calculating all distances of sample 1198
# Calculating all distances of sample 1199
# Calculating all distances of sample 1200

# %%
len(W_dist)
# Out:
# 500

# %%
W_dist = json.load(open('/content/distances700-1200.json'))

# %%
# for i in range(len(W_dist)):
#   W_dist[i][i+1000] = 1e9
w_dist = torch.Tensor(W_dist)

# %%
pred = w_dist.argmin(dim=1)

# %%
pred
# Out:
# tensor([2288, 2288, 2120, 2120, 2120, 2120, 2120, 2120, 2112, 2120, 2078, 2136,
#         2136, 2075, 2075, 2067, 2067, 2042, 2075, 2016, 2203, 2074, 2074, 2095,
#         2104, 2016, 1988, 1988, 1988, 1988, 2073, 2084, 2266, 2073, 1999, 1999,
#         2001, 1999, 1999, 1999, 2288, 2243, 2289, 2288, 2289, 2289, 2288, 2289,
#         2003, 2162, 1993, 4624, 2100, 2100, 2244, 2101, 2533, 2470, 2470, 2088,
#         2088, 2088, 2288, 2479, 2249,  882, 2470, 2208, 2479, 2288, 2506, 2590,
#         2507, 2507, 2592, 2345, 2507, 2507, 2507, 2507, 2400, 2533, 2535, 2535,
#         2535, 2535, 2600, 2535, 2609, 2609, 2550, 2349, 2592, 2592, 2550, 2592,
#         2321, 2550, 2592, 2592, 2600, 2559, 2600, 2563, 2608, 2601, 2473, 2567,
#         2627, 2320, 2439, 2436, 2583, 2585, 2435, 2523, 2522, 2435, 2585, 2435,
#         2365, 2603, 2579, 2601, 2470, 2470, 2559, 2579, 2470, 2466, 2562, 2521,
#         2364, 2459, 2562, 2562, 2562, 2562, 2561, 2561, 2466, 2480, 2533, 2533,
#         2458, 2435, 2435, 2586, 2586, 2592, 2547, 2545, 2547, 2562, 2609, 2603,
#         2319, 2575, 2639, 2608, 2566, 2562, 2523, 2562, 2608, 2608, 2570, 2367,
#         2609, 2563, 2313, 2318, 2529, 2565, 2565, 2520, 2561, 2562, 2520, 2364,
#         2921, 2900, 2906, 2928, 2906, 2900, 2906, 2921, 2906, 2921, 2761, 2919,
#         2913, 2901, 2699, 2761, 2902, 2761, 2760, 2919, 2729, 2689, 2689, 2729,
#         2729, 2723, 2657, 2723, 2725, 2723, 2680, 2680, 2658, 2657, 2657, 2729,
#         2808, 2811, 2808, 2680, 2949, 2652, 2782, 2782, 2759, 2782, 2780, 2780,
#         2949, 2652, 2801, 2687, 2728, 2645, 2643, 2728, 2728, 2796, 2728, 2794,
#         2734, 2734, 4624, 4621, 2716, 2924, 2924, 2714, 2734, 2924, 2659, 2652,
#         2651, 2659, 2847, 2847, 2662, 2847, 2847, 2847, 2761, 2761, 3131, 2761,
#         2946, 3137, 2930, 2761, 2761, 2946, 2902, 3249, 5269, 3249, 2904, 3249,
#         2904, 2904, 2904, 2904, 2901, 2918, 2835, 2919, 2901, 2902, 2901, 2764,
#         2901, 2901, 3258, 3253, 3036, 3167, 3035, 3036, 3036, 3001, 3167, 3035,
#         3230, 3230, 3190, 3281, 3281, 3190, 3269, 3230, 3230, 3281, 3001, 3008,
#         3001, 3168, 3039, 3167, 3168, 3167, 3039, 3036, 3136, 3153, 3245, 3097,
#         3099, 3155, 3245, 3231, 3263, 3153, 3256, 3094, 3256, 3253, 3254, 3169,
#         3223, 3253, 3253, 3258, 3153, 3264, 3288, 3155, 2971, 3223, 3030, 3030,
#         3030, 3153, 2982, 3136, 3277, 3218, 3136, 3138, 3136, 3136, 3218, 3270,
#         3240, 3243, 3242, 3251, 3243, 3256, 3240, 3243, 3243, 3240, 3137, 2662,
#         5214, 3230, 3081, 5215, 5215, 3281, 3281, 3281, 3196, 2664, 2664, 3230,
#         3230, 3281, 3230, 3236, 3230, 3231, 3023, 3027, 3023, 3023, 3023, 3023,
#         3028, 3029, 3028, 3027, 3418, 3612, 3449, 2878, 3612, 2878, 3412, 2939,
#         3612, 3449, 3538, 3349, 3349, 3534, 3538, 3410, 3538, 3407, 3306, 3606,
#         3342, 3342, 3364, 3387, 3470, 3314, 3343, 3500, 3375, 3382, 3606, 3349,
#         3606, 3342, 3340, 3390, 3319, 3535, 3339, 3340, 3418, 2067, 3440, 3418,
#         3418, 3418, 3418, 3418, 3418, 3418, 3422, 3422, 3388, 3383, 3422, 3600,
#         3422, 3388, 3367, 3383, 3300, 3306, 3366, 3396, 3368, 3301, 3308, 3305,
#         3305, 3308, 3311, 3418, 3412, 3412,  246, 2453, 3448, 3440,   49, 3412,
#         3352, 3354, 3354, 3354, 3415, 3322, 3440, 3417, 3359, 3328, 3301, 3407,
#         3407, 3606, 3797, 3407, 3407, 3440, 3407, 3300])

# %%
sum(y_train[pred]==y_test[700:1200])
# Out:
# tensor(485)
