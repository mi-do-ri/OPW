# %%
import torch
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
def OPW_w(x: torch.Tensor, y: torch.Tensor, a: torch.Tensor = None, b: torch.Tensor = None, std=1, verbose=0, lambda1=0.1, lambda2=10,
          tol=.5e-2, maxIter=20, p_norm='inf', metric='sqreuclidean'):
    assert y.size(1) == x.size(1), "The dimensions of instances in the input sequences must be the same!"
    N = x.size(0)
    M = y.size(0)
    col_x = torch.arange(1, N+1)/N
    col_x = col_x.view(N, 1)
    col_y = torch.arange(1, M+1)/M
    relative_pos = col_x-col_y

    l = torch.abs(relative_pos) / ((1/N**2 + 1/M**2)**0.5)
    P = torch.exp(-l**2/(2*std**2)) / (std*(2*np.pi)**0.5)

    S = lambda1 / (relative_pos**2 + 1)

    D = pdist2(x, y, metric=metric)

    K = P * torch.exp((S - D) / lambda2)

    if a is None:
        a = torch.ones(N, 1) / N

    if b is None:
        b = torch.ones(M, 1) / M

    ainvK = K / a   # [N, M]

    iter = 0
    u = torch.ones(N, 1) / N
    while iter < maxIter:
        u = 1. / torch.matmul(ainvK, (b / (torch.matmul(K.T, u))))
        
        iter += 1
        if iter % 20 == 1 or iter == maxIter:
            v = b / torch.matmul(K.T, u)    # [M, 1]
            u = 1 / torch.matmul(ainvK, v)  # [N, 1]

            criterion = torch.sum(torch.abs(v * torch.matmul(K.T, u) - b), dim=0)
            criterion = criterion.norm(p=float(p_norm))
            if abs(criterion) < tol:
                break

            iter += 1
            if verbose > 0:
                print(f"Iteration : {iter}, Criterion: {criterion}")

    U = K * D   # [N, M]
    
    dist = torch.sum(u * torch.matmul(U, v), dim=0)
    T = v.T * (u * K)
 
    return dist, T

# %%
def pdist2(X, Y, metric='sqreuclidean'):
    if metric.lower() == 'sqreuclidean':
        return distEucSqr(X, Y)
    elif metric.lower() == 'euclidean':
        return torch.sqrt(distEucSqr(X, Y))
    elif metric.lower() == 'L1':
        return distL1(X, Y)
    elif metric.lower() == 'cosine':
        return distCosine(X, Y)
    elif metric.lower() == 'emd':
        return distEmd(X, Y)
    elif metric.lower() == 'chisqr':
        return distChiSqr(X, Y)
    else:
        raise NotImplementedError(f'pdist - unknown metric: {metric}')


def distL1(x: torch.Tensor, y: torch.Tensor):
    return torch.abs(x.unsqueeze(1) - y).sum(dim=-1)


def distCosine(x: torch.Tensor, y: torch.Tensor, eps=1e-8):
    assert x.dtype == torch.float or y.dtype == torch.float, "Inputs must be of type float"
    cos = torch.nn.CosineSimilarity(dim=-1, eps=eps)
    return 1 - cos(x.unsqueeze(1), y)


def distEmd(x: torch.Tensor, y: torch.Tensor):
    x_cdf = torch.cumsum(x, dim=-1)
    y_cdf = torch.cumsum(y, dim=-1)

    return torch.abs(x_cdf.unsqueeze(1) - y_cdf).sum(dim=-1)


def distEucSqr(x: torch.Tensor, y: torch.Tensor):
    return torch.cdist(x, y, p=2)**2


def distChiSqr(x: torch.Tensor, y: torch.Tensor, eps=1e-10):
    a = x.unsqueeze(1) + y
    b = x.unsqueeze(1) - y
    return (b**2 / (a + eps)).sum(dim=-1) / 2

# %%
def get_utterances(path):
  X = []
  utterances = []
  count = 0
  with open(path, 'r') as f:
      length_X = len([line for line in f.read().splitlines()])
  with open(path, 'r') as f:
      for line in f.read().splitlines():
          count += 1
          frame = [-abs(float(i)) if i.startswith('-') else abs(float(i)) for i in line.split()]
          if len(frame) > 0:
            utterances.append(frame)
            if count == length_X:
              X.append(utterances)
          else:
            if len(utterances) > 0:
              X.append(utterances)
              utterances = []
          
  return X

# %%
X_train = get_utterances(path="/content/Train_Arabic_Digit.txt")
X_test = get_utterances(path="/content/Test_Arabic_Digit.txt")
print(f"Number of training sample: {len(X_train)}")
print(f"Number of testing sample: {len(X_test)}")
# Out:
# Number of training sample: 6600
# Number of testing sample: 2200

# %%
import torch
import numpy as np
import json 

n_class = torch.Tensor(torch.arange(0, 10)).view(10, 1)
y_train = n_class.expand_as(torch.empty((10, 660))).contiguous().view(6600)
y_test = n_class.expand_as(torch.empty((10, 220))).contiguous().view(2200)

# %%
with open('fe.json', 'w') as f:
    json.dump(3, f)

# %%
W_dist = []
for idx_X, X in enumerate(X_test):
    if idx_X < 2200 and idx_X >= 1700:
      print(f'Calculating all distances of sample {idx_X+1}')
      W_X = []
      for idx_Y, Y in enumerate(X_train):
          dist, minT = OPW_w(torch.Tensor(X), torch.Tensor(Y), verbose=0, lambda1=0.1, lambda2=10)
          W_X.append(dist.item())
      W_dist.append(W_X)

with open('/content/distances1700-2200.json', 'w') as f:
    json.dump(W_dist, f)
# Out:
# Calculating all distances of sample 1701
# Calculating all distances of sample 1702
# Calculating all distances of sample 1703
# Calculating all distances of sample 1704
# Calculating all distances of sample 1705
# Calculating all distances of sample 1706
# Calculating all distances of sample 1707
# Calculating all distances of sample 1708
# Calculating all distances of sample 1709
# Calculating all distances of sample 1710
# Calculating all distances of sample 1711
# Calculating all distances of sample 1712
# Calculating all distances of sample 1713
# Calculating all distances of sample 1714
# Calculating all distances of sample 1715
# Calculating all distances of sample 1716
# Calculating all distances of sample 1717
# Calculating all distances of sample 1718
# Calculating all distances of sample 1719
# Calculating all distances of sample 1720
# Calculating all distances of sample 1721
# Calculating all distances of sample 1722
# Calculating all distances of sample 1723
# Calculating all distances of sample 1724
# Calculating all distances of sample 1725
# Calculating all distances of sample 1726
# Calculating all distances of sample 1727
# Calculating all distances of sample 1728
# Calculating all distances of sample 1729
# Calculating all distances of sample 1730
# Calculating all distances of sample 1731
# Calculating all distances of sample 1732
# Calculating all distances of sample 1733
# Calculating all distances of sample 1734
# Calculating all distances of sample 1735
# Calculating all distances of sample 1736
# Calculating all distances of sample 1737
# Calculating all distances of sample 1738
# Calculating all distances of sample 1739
# Calculating all distances of sample 1740
# Calculating all distances of sample 1741
# Calculating all distances of sample 1742
# Calculating all distances of sample 1743
# Calculating all distances of sample 1744
# Calculating all distances of sample 1745
# Calculating all distances of sample 1746
# Calculating all distances of sample 1747
# Calculating all distances of sample 1748
# Calculating all distances of sample 1749
# Calculating all distances of sample 1750
# Calculating all distances of sample 1751
# Calculating all distances of sample 1752
# Calculating all distances of sample 1753
# Calculating all distances of sample 1754
# Calculating all distances of sample 1755
# Calculating all distances of sample 1756
# Calculating all distances of sample 1757
# Calculating all distances of sample 1758
# Calculating all distances of sample 1759
# Calculating all distances of sample 1760
# Calculating all distances of sample 1761
# Calculating all distances of sample 1762
# Calculating all distances of sample 1763
# Calculating all distances of sample 1764
# Calculating all distances of sample 1765
# Calculating all distances of sample 1766
# Calculating all distances of sample 1767
# Calculating all distances of sample 1768
# Calculating all distances of sample 1769
# Calculating all distances of sample 1770
# Calculating all distances of sample 1771
# Calculating all distances of sample 1772
# Calculating all distances of sample 1773
# Calculating all distances of sample 1774
# Calculating all distances of sample 1775
# Calculating all distances of sample 1776
# Calculating all distances of sample 1777
# Calculating all distances of sample 1778
# Calculating all distances of sample 1779
# Calculating all distances of sample 1780
# Calculating all distances of sample 1781
# Calculating all distances of sample 1782
# Calculating all distances of sample 1783
# Calculating all distances of sample 1784
# Calculating all distances of sample 1785
# Calculating all distances of sample 1786
# Calculating all distances of sample 1787
# Calculating all distances of sample 1788
# Calculating all distances of sample 1789
# Calculating all distances of sample 1790
# Calculating all distances of sample 1791
# Calculating all distances of sample 1792
# Calculating all distances of sample 1793
# Calculating all distances of sample 1794
# Calculating all distances of sample 1795
# Calculating all distances of sample 1796
# Calculating all distances of sample 1797
# Calculating all distances of sample 1798
# Calculating all distances of sample 1799
# Calculating all distances of sample 1800
# Calculating all distances of sample 1801
# Calculating all distances of sample 1802
# Calculating all distances of sample 1803
# Calculating all distances of sample 1804
# Calculating all distances of sample 1805
# Calculating all distances of sample 1806
# Calculating all distances of sample 1807
# Calculating all distances of sample 1808
# Calculating all distances of sample 1809
# Calculating all distances of sample 1810
# Calculating all distances of sample 1811
# Calculating all distances of sample 1812
# Calculating all distances of sample 1813
# Calculating all distances of sample 1814
# Calculating all distances of sample 1815
# Calculating all distances of sample 1816
# Calculating all distances of sample 1817
# Calculating all distances of sample 1818
# Calculating all distances of sample 1819
# Calculating all distances of sample 1820
# Calculating all distances of sample 1821
# Calculating all distances of sample 1822
# Calculating all distances of sample 1823
# Calculating all distances of sample 1824
# Calculating all distances of sample 1825
# Calculating all distances of sample 1826
# Calculating all distances of sample 1827
# Calculating all distances of sample 1828
# Calculating all distances of sample 1829
# Calculating all distances of sample 1830
# Calculating all distances of sample 1831
# Calculating all distances of sample 1832
# Calculating all distances of sample 1833
# Calculating all distances of sample 1834
# Calculating all distances of sample 1835
# Calculating all distances of sample 1836
# Calculating all distances of sample 1837
# Calculating all distances of sample 1838
# Calculating all distances of sample 1839
# Calculating all distances of sample 1840
# Calculating all distances of sample 1841
# Calculating all distances of sample 1842
# Calculating all distances of sample 1843
# Calculating all distances of sample 1844
# Calculating all distances of sample 1845
# Calculating all distances of sample 1846
# Calculating all distances of sample 1847
# Calculating all distances of sample 1848
# Calculating all distances of sample 1849
# Calculating all distances of sample 1850
# Calculating all distances of sample 1851
# Calculating all distances of sample 1852
# Calculating all distances of sample 1853
# Calculating all distances of sample 1854
# Calculating all distances of sample 1855
# Calculating all distances of sample 1856
# Calculating all distances of sample 1857
# Calculating all distances of sample 1858
# Calculating all distances of sample 1859
# Calculating all distances of sample 1860
# Calculating all distances of sample 1861
# Calculating all distances of sample 1862
# Calculating all distances of sample 1863
# Calculating all distances of sample 1864
# Calculating all distances of sample 1865
# Calculating all distances of sample 1866
# Calculating all distances of sample 1867
# Calculating all distances of sample 1868
# Calculating all distances of sample 1869
# Calculating all distances of sample 1870
# Calculating all distances of sample 1871
# Calculating all distances of sample 1872
# Calculating all distances of sample 1873
# Calculating all distances of sample 1874
# Calculating all distances of sample 1875
# Calculating all distances of sample 1876
# Calculating all distances of sample 1877
# Calculating all distances of sample 1878
# Calculating all distances of sample 1879
# Calculating all distances of sample 1880
# Calculating all distances of sample 1881
# Calculating all distances of sample 1882
# Calculating all distances of sample 1883
# Calculating all distances of sample 1884
# Calculating all distances of sample 1885
# Calculating all distances of sample 1886
# Calculating all distances of sample 1887
# Calculating all distances of sample 1888
# Calculating all distances of sample 1889
# Calculating all distances of sample 1890
# Calculating all distances of sample 1891
# Calculating all distances of sample 1892
# Calculating all distances of sample 1893
# Calculating all distances of sample 1894
# Calculating all distances of sample 1895
# Calculating all distances of sample 1896
# Calculating all distances of sample 1897
# Calculating all distances of sample 1898
# Calculating all distances of sample 1899
# Calculating all distances of sample 1900
# Calculating all distances of sample 1901
# Calculating all distances of sample 1902
# Calculating all distances of sample 1903
# Calculating all distances of sample 1904
# Calculating all distances of sample 1905
# Calculating all distances of sample 1906
# Calculating all distances of sample 1907
# Calculating all distances of sample 1908
# Calculating all distances of sample 1909
# Calculating all distances of sample 1910
# Calculating all distances of sample 1911
# Calculating all distances of sample 1912
# Calculating all distances of sample 1913
# Calculating all distances of sample 1914
# Calculating all distances of sample 1915
# Calculating all distances of sample 1916
# Calculating all distances of sample 1917
# Calculating all distances of sample 1918
# Calculating all distances of sample 1919
# Calculating all distances of sample 1920
# Calculating all distances of sample 1921
# Calculating all distances of sample 1922
# Calculating all distances of sample 1923
# Calculating all distances of sample 1924
# Calculating all distances of sample 1925
# Calculating all distances of sample 1926
# Calculating all distances of sample 1927
# Calculating all distances of sample 1928
# Calculating all distances of sample 1929
# Calculating all distances of sample 1930
# Calculating all distances of sample 1931
# Calculating all distances of sample 1932
# Calculating all distances of sample 1933
# Calculating all distances of sample 1934
# Calculating all distances of sample 1935
# Calculating all distances of sample 1936
# Calculating all distances of sample 1937
# Calculating all distances of sample 1938
# Calculating all distances of sample 1939
# Calculating all distances of sample 1940
# Calculating all distances of sample 1941
# Calculating all distances of sample 1942
# Calculating all distances of sample 1943
# Calculating all distances of sample 1944
# Calculating all distances of sample 1945
# Calculating all distances of sample 1946
# Calculating all distances of sample 1947
# Calculating all distances of sample 1948
# Calculating all distances of sample 1949
# Calculating all distances of sample 1950
# Calculating all distances of sample 1951
# Calculating all distances of sample 1952
# Calculating all distances of sample 1953
# Calculating all distances of sample 1954
# Calculating all distances of sample 1955
# Calculating all distances of sample 1956
# Calculating all distances of sample 1957
# Calculating all distances of sample 1958
# Calculating all distances of sample 1959
# Calculating all distances of sample 1960
# Calculating all distances of sample 1961
# Calculating all distances of sample 1962
# Calculating all distances of sample 1963
# Calculating all distances of sample 1964
# Calculating all distances of sample 1965
# Calculating all distances of sample 1966
# Calculating all distances of sample 1967
# Calculating all distances of sample 1968
# Calculating all distances of sample 1969
# Calculating all distances of sample 1970
# Calculating all distances of sample 1971
# Calculating all distances of sample 1972
# Calculating all distances of sample 1973
# Calculating all distances of sample 1974
# Calculating all distances of sample 1975
# Calculating all distances of sample 1976
# Calculating all distances of sample 1977
# Calculating all distances of sample 1978
# Calculating all distances of sample 1979
# Calculating all distances of sample 1980
# Calculating all distances of sample 1981
# Calculating all distances of sample 1982
# Calculating all distances of sample 1983
# Calculating all distances of sample 1984
# Calculating all distances of sample 1985
# Calculating all distances of sample 1986
# Calculating all distances of sample 1987
# Calculating all distances of sample 1988
# Calculating all distances of sample 1989
# Calculating all distances of sample 1990
# Calculating all distances of sample 1991
# Calculating all distances of sample 1992
# Calculating all distances of sample 1993
# Calculating all distances of sample 1994
# Calculating all distances of sample 1995
# Calculating all distances of sample 1996
# Calculating all distances of sample 1997
# Calculating all distances of sample 1998
# Calculating all distances of sample 1999
# Calculating all distances of sample 2000
# Calculating all distances of sample 2001
# Calculating all distances of sample 2002
# Calculating all distances of sample 2003
# Calculating all distances of sample 2004
# Calculating all distances of sample 2005
# Calculating all distances of sample 2006
# Calculating all distances of sample 2007
# Calculating all distances of sample 2008
# Calculating all distances of sample 2009
# Calculating all distances of sample 2010
# Calculating all distances of sample 2011
# Calculating all distances of sample 2012
# Calculating all distances of sample 2013
# Calculating all distances of sample 2014
# Calculating all distances of sample 2015
# Calculating all distances of sample 2016
# Calculating all distances of sample 2017
# Calculating all distances of sample 2018
# Calculating all distances of sample 2019
# Calculating all distances of sample 2020
# Calculating all distances of sample 2021
# Calculating all distances of sample 2022
# Calculating all distances of sample 2023
# Calculating all distances of sample 2024
# Calculating all distances of sample 2025
# Calculating all distances of sample 2026
# Calculating all distances of sample 2027
# Calculating all distances of sample 2028
# Calculating all distances of sample 2029
# Calculating all distances of sample 2030
# Calculating all distances of sample 2031
# Calculating all distances of sample 2032
# Calculating all distances of sample 2033
# Calculating all distances of sample 2034
# Calculating all distances of sample 2035
# Calculating all distances of sample 2036
# Calculating all distances of sample 2037
# Calculating all distances of sample 2038
# Calculating all distances of sample 2039
# Calculating all distances of sample 2040
# Calculating all distances of sample 2041
# Calculating all distances of sample 2042
# Calculating all distances of sample 2043
# Calculating all distances of sample 2044
# Calculating all distances of sample 2045
# Calculating all distances of sample 2046
# Calculating all distances of sample 2047
# Calculating all distances of sample 2048
# Calculating all distances of sample 2049
# Calculating all distances of sample 2050
# Calculating all distances of sample 2051
# Calculating all distances of sample 2052
# Calculating all distances of sample 2053
# Calculating all distances of sample 2054
# Calculating all distances of sample 2055
# Calculating all distances of sample 2056
# Calculating all distances of sample 2057
# Calculating all distances of sample 2058
# Calculating all distances of sample 2059
# Calculating all distances of sample 2060
# Calculating all distances of sample 2061
# Calculating all distances of sample 2062
# Calculating all distances of sample 2063
# Calculating all distances of sample 2064
# Calculating all distances of sample 2065
# Calculating all distances of sample 2066
# Calculating all distances of sample 2067
# Calculating all distances of sample 2068
# Calculating all distances of sample 2069
# Calculating all distances of sample 2070
# Calculating all distances of sample 2071
# Calculating all distances of sample 2072
# Calculating all distances of sample 2073
# Calculating all distances of sample 2074
# Calculating all distances of sample 2075
# Calculating all distances of sample 2076
# Calculating all distances of sample 2077
# Calculating all distances of sample 2078
# Calculating all distances of sample 2079
# Calculating all distances of sample 2080
# Calculating all distances of sample 2081
# Calculating all distances of sample 2082
# Calculating all distances of sample 2083
# Calculating all distances of sample 2084
# Calculating all distances of sample 2085
# Calculating all distances of sample 2086
# Calculating all distances of sample 2087
# Calculating all distances of sample 2088
# Calculating all distances of sample 2089
# Calculating all distances of sample 2090
# Calculating all distances of sample 2091
# Calculating all distances of sample 2092
# Calculating all distances of sample 2093
# Calculating all distances of sample 2094
# Calculating all distances of sample 2095
# Calculating all distances of sample 2096
# Calculating all distances of sample 2097
# Calculating all distances of sample 2098
# Calculating all distances of sample 2099
# Calculating all distances of sample 2100
# Calculating all distances of sample 2101
# Calculating all distances of sample 2102
# Calculating all distances of sample 2103
# Calculating all distances of sample 2104
# Calculating all distances of sample 2105
# Calculating all distances of sample 2106
# Calculating all distances of sample 2107
# Calculating all distances of sample 2108
# Calculating all distances of sample 2109
# Calculating all distances of sample 2110
# Calculating all distances of sample 2111
# Calculating all distances of sample 2112
# Calculating all distances of sample 2113
# Calculating all distances of sample 2114
# Calculating all distances of sample 2115
# Calculating all distances of sample 2116
# Calculating all distances of sample 2117
# Calculating all distances of sample 2118
# Calculating all distances of sample 2119
# Calculating all distances of sample 2120
# Calculating all distances of sample 2121
# Calculating all distances of sample 2122
# Calculating all distances of sample 2123
# Calculating all distances of sample 2124
# Calculating all distances of sample 2125
# Calculating all distances of sample 2126
# Calculating all distances of sample 2127
# Calculating all distances of sample 2128
# Calculating all distances of sample 2129
# Calculating all distances of sample 2130
# Calculating all distances of sample 2131
# Calculating all distances of sample 2132
# Calculating all distances of sample 2133
# Calculating all distances of sample 2134
# Calculating all distances of sample 2135
# Calculating all distances of sample 2136
# Calculating all distances of sample 2137
# Calculating all distances of sample 2138
# Calculating all distances of sample 2139
# Calculating all distances of sample 2140
# Calculating all distances of sample 2141
# Calculating all distances of sample 2142
# Calculating all distances of sample 2143
# Calculating all distances of sample 2144
# Calculating all distances of sample 2145
# Calculating all distances of sample 2146
# Calculating all distances of sample 2147
# Calculating all distances of sample 2148
# Calculating all distances of sample 2149
# Calculating all distances of sample 2150
# Calculating all distances of sample 2151
# Calculating all distances of sample 2152
# Calculating all distances of sample 2153
# Calculating all distances of sample 2154
# Calculating all distances of sample 2155
# Calculating all distances of sample 2156
# Calculating all distances of sample 2157
# Calculating all distances of sample 2158
# Calculating all distances of sample 2159
# Calculating all distances of sample 2160
# Calculating all distances of sample 2161
# Calculating all distances of sample 2162
# Calculating all distances of sample 2163
# Calculating all distances of sample 2164
# Calculating all distances of sample 2165
# Calculating all distances of sample 2166
# Calculating all distances of sample 2167
# Calculating all distances of sample 2168
# Calculating all distances of sample 2169
# Calculating all distances of sample 2170
# Calculating all distances of sample 2171
# Calculating all distances of sample 2172
# Calculating all distances of sample 2173
# Calculating all distances of sample 2174
# Calculating all distances of sample 2175
# Calculating all distances of sample 2176
# Calculating all distances of sample 2177
# Calculating all distances of sample 2178
# Calculating all distances of sample 2179
# Calculating all distances of sample 2180
# Calculating all distances of sample 2181
# Calculating all distances of sample 2182
# Calculating all distances of sample 2183
# Calculating all distances of sample 2184
# Calculating all distances of sample 2185
# Calculating all distances of sample 2186
# Calculating all distances of sample 2187
# Calculating all distances of sample 2188
# Calculating all distances of sample 2189
# Calculating all distances of sample 2190
# Calculating all distances of sample 2191
# Calculating all distances of sample 2192
# Calculating all distances of sample 2193
# Calculating all distances of sample 2194
# Calculating all distances of sample 2195
# Calculating all distances of sample 2196
# Calculating all distances of sample 2197
# Calculating all distances of sample 2198
# Calculating all distances of sample 2199
# Calculating all distances of sample 2200

# %%
len(W_dist)
# Out:
# 500

# %%
W_dist = json.load(open('/content/distances1700-2200.json'))

# %%
# for i in range(len(W_dist)):
#   W_dist[i][i+1000] = 1e9
w_dist = torch.Tensor(W_dist)

# %%
pred = w_dist.argmin(dim=1)

# %%
pred
# Out:
# tensor([5266, 5266, 3265, 5259, 5100, 5256, 5113, 5245, 5246, 5266, 5257, 4967,
#         4967, 4954, 5269, 5269, 4995, 3227, 5269, 5269, 5228, 5154, 5220, 5154,
#         4998, 4998, 5161, 5154, 4796, 4791, 5176, 5213, 4957, 5206, 5213, 5241,
#         5278, 4959, 5215, 5213, 5131, 4963, 5170, 5213, 5213, 5206, 5170, 5213,
#         4957, 5170, 5067, 4961, 4963, 4961, 4961, 5127, 4963, 4961, 4998, 4961,
#         5561, 5468, 5561, 5560, 5586, 5468, 5468, 5770, 5770, 5770, 5734, 5575,
#         5771, 5575, 5737, 5574, 5738, 5388, 5774, 5388, 5296, 5296, 5296, 5296,
#         5374, 5296, 5374, 5296, 5373, 5296, 5341, 5347, 5341, 5346, 5343, 5347,
#         5343, 5346, 5341, 5343, 5586, 5586, 5560, 5586, 5586, 5589, 5586, 5586,
#         5586, 5586, 5370, 5454, 5454, 5450, 5454, 5454, 5406, 5406, 5344, 5454,
#         5579, 5579, 5568, 5568, 5579, 5579, 5568, 5568, 5576, 5578, 5580, 5582,
#         5584, 5582, 5584, 5584, 5583, 5584, 5584, 5584, 5560, 5770, 5574, 5560,
#         5560, 5560, 5560, 5560, 5560, 5382, 5770, 5920, 5770, 5770, 5772, 5771,
#         5737, 5772, 5770, 5772, 5583, 5774, 5388, 5388, 5774, 5388, 5388, 5380,
#         5774, 5774, 5824, 5641, 5851, 5803, 5808, 5803, 5803, 5808, 5851, 5824,
#         5902, 5902, 5902, 5901, 5780, 5780, 5902, 5901, 5902, 5902, 5829, 5734,
#         5897, 5890, 5733, 5658, 5734, 5735, 5731, 5733, 5861, 5865, 5615, 5865,
#         5865, 5861, 5865, 5865, 5865, 5861, 5800, 5800, 5829, 5617, 5735, 5618,
#         5618, 5617, 5617, 5617, 5614, 5907, 5907, 5624, 5907, 5760, 5760, 5770,
#         5770, 5760, 5770, 5770, 5770, 5772, 5925, 5772, 5770, 5770, 5770, 5772,
#         5732, 5756, 5886, 5753, 5886, 5734, 5771, 5886, 5883, 5753, 5625, 5762,
#         5611, 5787, 5787, 5873, 5938, 5938, 5877, 5902, 5625, 5861, 5611, 5762,
#         5760, 5762, 5762, 5762, 5760, 5762, 5702, 5668, 5668, 5661, 5795, 5920,
#         5702, 5661, 5826, 5661, 6127, 6126, 6127, 6129, 6126, 6126, 6127, 6127,
#         6127, 6129, 6209, 6239, 6035, 6115, 6239, 5955, 5954, 5952, 5955, 6239,
#         6024, 6004, 6022, 6116, 6101, 6021, 6009, 5947, 6021, 6330, 6045, 6116,
#         5947, 6117, 6117, 6152, 5947, 5943, 6117, 6047, 6054, 6248, 6052, 6248,
#         6053, 6248, 6248, 6434, 6248, 6248, 6028, 6151, 6028, 6113, 6022, 6119,
#         6022, 6117, 6187, 6151, 6049, 6049, 6168, 1815, 6161, 6161, 6235, 6161,
#         6161, 6161, 5954, 6099, 5954, 5954, 5957, 5957, 5957, 5957, 5957, 5957,
#         6201, 6082, 6082, 6050, 6209, 6209, 6209, 6433, 6209, 5968, 6133, 6133,
#         6082, 6082, 6315, 6315, 6315, 6134, 6280, 6082, 6395, 6050, 6050, 6053,
#         6153, 6050, 6053, 5951, 6239, 6053, 6469, 6469, 6309, 6469, 6338, 6307,
#         6469, 6469, 6469, 6469, 6447, 6441, 6598, 6598, 3297, 6597, 6596, 6597,
#         6597, 6596, 6571, 6283, 6462, 6570, 6391, 6549, 6565, 6301, 6557, 6465,
#         6421, 6526, 6489, 6526, 6279, 6528, 6489, 6573, 6467, 6270, 6589, 6589,
#         6375, 6271, 6276, 6526, 6488, 6271, 6276, 6586, 6421, 6528, 6521, 6589,
#         6521, 6272, 6526, 6526, 6423, 6520, 6511, 6556, 6433, 6548, 6548, 6589,
#         6556, 6433, 6433, 6433, 6555, 6557, 6453, 6555, 6558, 6552, 6433, 6545,
#         6552, 6548, 6493, 6599, 6459, 6459, 6388, 6592, 6534, 6446, 6449, 6452,
#         6493, 6367, 6362, 6459, 6457, 6367, 6420, 6362, 6595, 6420, 6493, 6383,
#         6384, 6383, 6281, 6383, 6281, 6383, 6384, 6383])

# %%
sum(y_train[pred]==y_test[1700:2200])
# Out:
# tensor(496)
