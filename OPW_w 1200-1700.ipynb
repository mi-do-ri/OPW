# %%
import torch
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
def OPW_w(x: torch.Tensor, y: torch.Tensor, a: torch.Tensor = None, b: torch.Tensor = None, std=1, verbose=0, lambda1=0.1, lambda2=10,
          tol=.5e-2, maxIter=20, p_norm='inf', metric='sqreuclidean'):
    assert y.size(1) == x.size(1), "The dimensions of instances in the input sequences must be the same!"
    N = x.size(0)
    M = y.size(0)
    col_x = torch.arange(1, N+1)/N
    col_x = col_x.view(N, 1)
    col_y = torch.arange(1, M+1)/M
    relative_pos = col_x-col_y

    l = torch.abs(relative_pos) / ((1/N**2 + 1/M**2)**0.5)
    P = torch.exp(-l**2/(2*std**2)) / (std*(2*np.pi)**0.5)

    S = lambda1 / (relative_pos**2 + 1)

    D = pdist2(x, y, metric=metric)

    K = P * torch.exp((S - D) / lambda2)

    if a is None:
        a = torch.ones(N, 1) / N

    if b is None:
        b = torch.ones(M, 1) / M

    ainvK = K / a   # [N, M]

    iter = 0
    u = torch.ones(N, 1) / N
    while iter < maxIter:
        u = 1. / torch.matmul(ainvK, (b / (torch.matmul(K.T, u))))
        
        iter += 1
        if iter % 20 == 1 or iter == maxIter:
            v = b / torch.matmul(K.T, u)    # [M, 1]
            u = 1 / torch.matmul(ainvK, v)  # [N, 1]

            criterion = torch.sum(torch.abs(v * torch.matmul(K.T, u) - b), dim=0)
            criterion = criterion.norm(p=float(p_norm))
            if abs(criterion) < tol:
                break

            iter += 1
            if verbose > 0:
                print(f"Iteration : {iter}, Criterion: {criterion}")

    U = K * D   # [N, M]
    
    dist = torch.sum(u * torch.matmul(U, v), dim=0)
    T = v.T * (u * K)
 
    return dist, T

# %%
def pdist2(X, Y, metric='sqreuclidean'):
    if metric.lower() == 'sqreuclidean':
        return distEucSqr(X, Y)
    elif metric.lower() == 'euclidean':
        return torch.sqrt(distEucSqr(X, Y))
    elif metric.lower() == 'L1':
        return distL1(X, Y)
    elif metric.lower() == 'cosine':
        return distCosine(X, Y)
    elif metric.lower() == 'emd':
        return distEmd(X, Y)
    elif metric.lower() == 'chisqr':
        return distChiSqr(X, Y)
    else:
        raise NotImplementedError(f'pdist - unknown metric: {metric}')


def distL1(x: torch.Tensor, y: torch.Tensor):
    return torch.abs(x.unsqueeze(1) - y).sum(dim=-1)


def distCosine(x: torch.Tensor, y: torch.Tensor, eps=1e-8):
    assert x.dtype == torch.float or y.dtype == torch.float, "Inputs must be of type float"
    cos = torch.nn.CosineSimilarity(dim=-1, eps=eps)
    return 1 - cos(x.unsqueeze(1), y)


def distEmd(x: torch.Tensor, y: torch.Tensor):
    x_cdf = torch.cumsum(x, dim=-1)
    y_cdf = torch.cumsum(y, dim=-1)

    return torch.abs(x_cdf.unsqueeze(1) - y_cdf).sum(dim=-1)


def distEucSqr(x: torch.Tensor, y: torch.Tensor):
    return torch.cdist(x, y, p=2)**2


def distChiSqr(x: torch.Tensor, y: torch.Tensor, eps=1e-10):
    a = x.unsqueeze(1) + y
    b = x.unsqueeze(1) - y
    return (b**2 / (a + eps)).sum(dim=-1) / 2

# %%
def get_utterances(path):
  X = []
  utterances = []
  count = 0
  with open(path, 'r') as f:
      length_X = len([line for line in f.read().splitlines()])
  with open(path, 'r') as f:
      for line in f.read().splitlines():
          count += 1
          frame = [-abs(float(i)) if i.startswith('-') else abs(float(i)) for i in line.split()]
          if len(frame) > 0:
            utterances.append(frame)
            if count == length_X:
              X.append(utterances)
          else:
            if len(utterances) > 0:
              X.append(utterances)
              utterances = []
          
  return X

# %%
X_train = get_utterances(path="/content/Train_Arabic_Digit.txt")
X_test = get_utterances(path="/content/Test_Arabic_Digit.txt")
print(f"Number of training sample: {len(X_train)}")
print(f"Number of testing sample: {len(X_test)}")
# Out:
# Number of training sample: 6600
# Number of testing sample: 2200

# %%
import torch
import numpy as np
import json 

n_class = torch.Tensor(torch.arange(0, 10)).view(10, 1)
y_train = n_class.expand_as(torch.empty((10, 660))).contiguous().view(6600)
y_test = n_class.expand_as(torch.empty((10, 220))).contiguous().view(2200)

# %%
with open('fe.json', 'w') as f:
    json.dump(3, f)

# %%
W_dist = []
for idx_X, X in enumerate(X_test):
    if idx_X < 1700 and idx_X >= 1200:
      print(f'Calculating all distances of sample {idx_X+1}')
      W_X = []
      for idx_Y, Y in enumerate(X_train):
          dist, minT = OPW_w(torch.Tensor(X), torch.Tensor(Y), verbose=0, lambda1=0.1, lambda2=10)
          W_X.append(dist.item())
      W_dist.append(W_X)

with open('/content/distances1200-1700.json', 'w') as f:
    json.dump(W_dist, f)
# Out:
# Calculating all distances of sample 1201
# Calculating all distances of sample 1202
# Calculating all distances of sample 1203
# Calculating all distances of sample 1204
# Calculating all distances of sample 1205
# Calculating all distances of sample 1206
# Calculating all distances of sample 1207
# Calculating all distances of sample 1208
# Calculating all distances of sample 1209
# Calculating all distances of sample 1210
# Calculating all distances of sample 1211
# Calculating all distances of sample 1212
# Calculating all distances of sample 1213
# Calculating all distances of sample 1214
# Calculating all distances of sample 1215
# Calculating all distances of sample 1216
# Calculating all distances of sample 1217
# Calculating all distances of sample 1218
# Calculating all distances of sample 1219
# Calculating all distances of sample 1220
# Calculating all distances of sample 1221
# Calculating all distances of sample 1222
# Calculating all distances of sample 1223
# Calculating all distances of sample 1224
# Calculating all distances of sample 1225
# Calculating all distances of sample 1226
# Calculating all distances of sample 1227
# Calculating all distances of sample 1228
# Calculating all distances of sample 1229
# Calculating all distances of sample 1230
# Calculating all distances of sample 1231
# Calculating all distances of sample 1232
# Calculating all distances of sample 1233
# Calculating all distances of sample 1234
# Calculating all distances of sample 1235
# Calculating all distances of sample 1236
# Calculating all distances of sample 1237
# Calculating all distances of sample 1238
# Calculating all distances of sample 1239
# Calculating all distances of sample 1240
# Calculating all distances of sample 1241
# Calculating all distances of sample 1242
# Calculating all distances of sample 1243
# Calculating all distances of sample 1244
# Calculating all distances of sample 1245
# Calculating all distances of sample 1246
# Calculating all distances of sample 1247
# Calculating all distances of sample 1248
# Calculating all distances of sample 1249
# Calculating all distances of sample 1250
# Calculating all distances of sample 1251
# Calculating all distances of sample 1252
# Calculating all distances of sample 1253
# Calculating all distances of sample 1254
# Calculating all distances of sample 1255
# Calculating all distances of sample 1256
# Calculating all distances of sample 1257
# Calculating all distances of sample 1258
# Calculating all distances of sample 1259
# Calculating all distances of sample 1260
# Calculating all distances of sample 1261
# Calculating all distances of sample 1262
# Calculating all distances of sample 1263
# Calculating all distances of sample 1264
# Calculating all distances of sample 1265
# Calculating all distances of sample 1266
# Calculating all distances of sample 1267
# Calculating all distances of sample 1268
# Calculating all distances of sample 1269
# Calculating all distances of sample 1270
# Calculating all distances of sample 1271
# Calculating all distances of sample 1272
# Calculating all distances of sample 1273
# Calculating all distances of sample 1274
# Calculating all distances of sample 1275
# Calculating all distances of sample 1276
# Calculating all distances of sample 1277
# Calculating all distances of sample 1278
# Calculating all distances of sample 1279
# Calculating all distances of sample 1280
# Calculating all distances of sample 1281
# Calculating all distances of sample 1282
# Calculating all distances of sample 1283
# Calculating all distances of sample 1284
# Calculating all distances of sample 1285
# Calculating all distances of sample 1286
# Calculating all distances of sample 1287
# Calculating all distances of sample 1288
# Calculating all distances of sample 1289
# Calculating all distances of sample 1290
# Calculating all distances of sample 1291
# Calculating all distances of sample 1292
# Calculating all distances of sample 1293
# Calculating all distances of sample 1294
# Calculating all distances of sample 1295
# Calculating all distances of sample 1296
# Calculating all distances of sample 1297
# Calculating all distances of sample 1298
# Calculating all distances of sample 1299
# Calculating all distances of sample 1300
# Calculating all distances of sample 1301
# Calculating all distances of sample 1302
# Calculating all distances of sample 1303
# Calculating all distances of sample 1304
# Calculating all distances of sample 1305
# Calculating all distances of sample 1306
# Calculating all distances of sample 1307
# Calculating all distances of sample 1308
# Calculating all distances of sample 1309
# Calculating all distances of sample 1310
# Calculating all distances of sample 1311
# Calculating all distances of sample 1312
# Calculating all distances of sample 1313
# Calculating all distances of sample 1314
# Calculating all distances of sample 1315
# Calculating all distances of sample 1316
# Calculating all distances of sample 1317
# Calculating all distances of sample 1318
# Calculating all distances of sample 1319
# Calculating all distances of sample 1320
# Calculating all distances of sample 1321
# Calculating all distances of sample 1322
# Calculating all distances of sample 1323
# Calculating all distances of sample 1324
# Calculating all distances of sample 1325
# Calculating all distances of sample 1326
# Calculating all distances of sample 1327
# Calculating all distances of sample 1328
# Calculating all distances of sample 1329
# Calculating all distances of sample 1330
# Calculating all distances of sample 1331
# Calculating all distances of sample 1332
# Calculating all distances of sample 1333
# Calculating all distances of sample 1334
# Calculating all distances of sample 1335
# Calculating all distances of sample 1336
# Calculating all distances of sample 1337
# Calculating all distances of sample 1338
# Calculating all distances of sample 1339
# Calculating all distances of sample 1340
# Calculating all distances of sample 1341
# Calculating all distances of sample 1342
# Calculating all distances of sample 1343
# Calculating all distances of sample 1344
# Calculating all distances of sample 1345
# Calculating all distances of sample 1346
# Calculating all distances of sample 1347
# Calculating all distances of sample 1348
# Calculating all distances of sample 1349
# Calculating all distances of sample 1350
# Calculating all distances of sample 1351
# Calculating all distances of sample 1352
# Calculating all distances of sample 1353
# Calculating all distances of sample 1354
# Calculating all distances of sample 1355
# Calculating all distances of sample 1356
# Calculating all distances of sample 1357
# Calculating all distances of sample 1358
# Calculating all distances of sample 1359
# Calculating all distances of sample 1360
# Calculating all distances of sample 1361
# Calculating all distances of sample 1362
# Calculating all distances of sample 1363
# Calculating all distances of sample 1364
# Calculating all distances of sample 1365
# Calculating all distances of sample 1366
# Calculating all distances of sample 1367
# Calculating all distances of sample 1368
# Calculating all distances of sample 1369
# Calculating all distances of sample 1370
# Calculating all distances of sample 1371
# Calculating all distances of sample 1372
# Calculating all distances of sample 1373
# Calculating all distances of sample 1374
# Calculating all distances of sample 1375
# Calculating all distances of sample 1376
# Calculating all distances of sample 1377
# Calculating all distances of sample 1378
# Calculating all distances of sample 1379
# Calculating all distances of sample 1380
# Calculating all distances of sample 1381
# Calculating all distances of sample 1382
# Calculating all distances of sample 1383
# Calculating all distances of sample 1384
# Calculating all distances of sample 1385
# Calculating all distances of sample 1386
# Calculating all distances of sample 1387
# Calculating all distances of sample 1388
# Calculating all distances of sample 1389
# Calculating all distances of sample 1390
# Calculating all distances of sample 1391
# Calculating all distances of sample 1392
# Calculating all distances of sample 1393
# Calculating all distances of sample 1394
# Calculating all distances of sample 1395
# Calculating all distances of sample 1396
# Calculating all distances of sample 1397
# Calculating all distances of sample 1398
# Calculating all distances of sample 1399
# Calculating all distances of sample 1400
# Calculating all distances of sample 1401
# Calculating all distances of sample 1402
# Calculating all distances of sample 1403
# Calculating all distances of sample 1404
# Calculating all distances of sample 1405
# Calculating all distances of sample 1406
# Calculating all distances of sample 1407
# Calculating all distances of sample 1408
# Calculating all distances of sample 1409
# Calculating all distances of sample 1410
# Calculating all distances of sample 1411
# Calculating all distances of sample 1412
# Calculating all distances of sample 1413
# Calculating all distances of sample 1414
# Calculating all distances of sample 1415
# Calculating all distances of sample 1416
# Calculating all distances of sample 1417
# Calculating all distances of sample 1418
# Calculating all distances of sample 1419
# Calculating all distances of sample 1420
# Calculating all distances of sample 1421
# Calculating all distances of sample 1422
# Calculating all distances of sample 1423
# Calculating all distances of sample 1424
# Calculating all distances of sample 1425
# Calculating all distances of sample 1426
# Calculating all distances of sample 1427
# Calculating all distances of sample 1428
# Calculating all distances of sample 1429
# Calculating all distances of sample 1430
# Calculating all distances of sample 1431
# Calculating all distances of sample 1432
# Calculating all distances of sample 1433
# Calculating all distances of sample 1434
# Calculating all distances of sample 1435
# Calculating all distances of sample 1436
# Calculating all distances of sample 1437
# Calculating all distances of sample 1438
# Calculating all distances of sample 1439
# Calculating all distances of sample 1440
# Calculating all distances of sample 1441
# Calculating all distances of sample 1442
# Calculating all distances of sample 1443
# Calculating all distances of sample 1444
# Calculating all distances of sample 1445
# Calculating all distances of sample 1446
# Calculating all distances of sample 1447
# Calculating all distances of sample 1448
# Calculating all distances of sample 1449
# Calculating all distances of sample 1450
# Calculating all distances of sample 1451
# Calculating all distances of sample 1452
# Calculating all distances of sample 1453
# Calculating all distances of sample 1454
# Calculating all distances of sample 1455
# Calculating all distances of sample 1456
# Calculating all distances of sample 1457
# Calculating all distances of sample 1458
# Calculating all distances of sample 1459
# Calculating all distances of sample 1460
# Calculating all distances of sample 1461
# Calculating all distances of sample 1462
# Calculating all distances of sample 1463
# Calculating all distances of sample 1464
# Calculating all distances of sample 1465
# Calculating all distances of sample 1466
# Calculating all distances of sample 1467
# Calculating all distances of sample 1468
# Calculating all distances of sample 1469
# Calculating all distances of sample 1470
# Calculating all distances of sample 1471
# Calculating all distances of sample 1472
# Calculating all distances of sample 1473
# Calculating all distances of sample 1474
# Calculating all distances of sample 1475
# Calculating all distances of sample 1476
# Calculating all distances of sample 1477
# Calculating all distances of sample 1478
# Calculating all distances of sample 1479
# Calculating all distances of sample 1480
# Calculating all distances of sample 1481
# Calculating all distances of sample 1482
# Calculating all distances of sample 1483
# Calculating all distances of sample 1484
# Calculating all distances of sample 1485
# Calculating all distances of sample 1486
# Calculating all distances of sample 1487
# Calculating all distances of sample 1488
# Calculating all distances of sample 1489
# Calculating all distances of sample 1490
# Calculating all distances of sample 1491
# Calculating all distances of sample 1492
# Calculating all distances of sample 1493
# Calculating all distances of sample 1494
# Calculating all distances of sample 1495
# Calculating all distances of sample 1496
# Calculating all distances of sample 1497
# Calculating all distances of sample 1498
# Calculating all distances of sample 1499
# Calculating all distances of sample 1500
# Calculating all distances of sample 1501
# Calculating all distances of sample 1502
# Calculating all distances of sample 1503
# Calculating all distances of sample 1504
# Calculating all distances of sample 1505
# Calculating all distances of sample 1506
# Calculating all distances of sample 1507
# Calculating all distances of sample 1508
# Calculating all distances of sample 1509
# Calculating all distances of sample 1510
# Calculating all distances of sample 1511
# Calculating all distances of sample 1512
# Calculating all distances of sample 1513
# Calculating all distances of sample 1514
# Calculating all distances of sample 1515
# Calculating all distances of sample 1516
# Calculating all distances of sample 1517
# Calculating all distances of sample 1518
# Calculating all distances of sample 1519
# Calculating all distances of sample 1520
# Calculating all distances of sample 1521
# Calculating all distances of sample 1522
# Calculating all distances of sample 1523
# Calculating all distances of sample 1524
# Calculating all distances of sample 1525
# Calculating all distances of sample 1526
# Calculating all distances of sample 1527
# Calculating all distances of sample 1528
# Calculating all distances of sample 1529
# Calculating all distances of sample 1530
# Calculating all distances of sample 1531
# Calculating all distances of sample 1532
# Calculating all distances of sample 1533
# Calculating all distances of sample 1534
# Calculating all distances of sample 1535
# Calculating all distances of sample 1536
# Calculating all distances of sample 1537
# Calculating all distances of sample 1538
# Calculating all distances of sample 1539
# Calculating all distances of sample 1540
# Calculating all distances of sample 1541
# Calculating all distances of sample 1542
# Calculating all distances of sample 1543
# Calculating all distances of sample 1544
# Calculating all distances of sample 1545
# Calculating all distances of sample 1546
# Calculating all distances of sample 1547
# Calculating all distances of sample 1548
# Calculating all distances of sample 1549
# Calculating all distances of sample 1550
# Calculating all distances of sample 1551
# Calculating all distances of sample 1552
# Calculating all distances of sample 1553
# Calculating all distances of sample 1554
# Calculating all distances of sample 1555
# Calculating all distances of sample 1556
# Calculating all distances of sample 1557
# Calculating all distances of sample 1558
# Calculating all distances of sample 1559
# Calculating all distances of sample 1560
# Calculating all distances of sample 1561
# Calculating all distances of sample 1562
# Calculating all distances of sample 1563
# Calculating all distances of sample 1564
# Calculating all distances of sample 1565
# Calculating all distances of sample 1566
# Calculating all distances of sample 1567
# Calculating all distances of sample 1568
# Calculating all distances of sample 1569
# Calculating all distances of sample 1570
# Calculating all distances of sample 1571
# Calculating all distances of sample 1572
# Calculating all distances of sample 1573
# Calculating all distances of sample 1574
# Calculating all distances of sample 1575
# Calculating all distances of sample 1576
# Calculating all distances of sample 1577
# Calculating all distances of sample 1578
# Calculating all distances of sample 1579
# Calculating all distances of sample 1580
# Calculating all distances of sample 1581
# Calculating all distances of sample 1582
# Calculating all distances of sample 1583
# Calculating all distances of sample 1584
# Calculating all distances of sample 1585
# Calculating all distances of sample 1586
# Calculating all distances of sample 1587
# Calculating all distances of sample 1588
# Calculating all distances of sample 1589
# Calculating all distances of sample 1590
# Calculating all distances of sample 1591
# Calculating all distances of sample 1592
# Calculating all distances of sample 1593
# Calculating all distances of sample 1594
# Calculating all distances of sample 1595
# Calculating all distances of sample 1596
# Calculating all distances of sample 1597
# Calculating all distances of sample 1598
# Calculating all distances of sample 1599
# Calculating all distances of sample 1600
# Calculating all distances of sample 1601
# Calculating all distances of sample 1602
# Calculating all distances of sample 1603
# Calculating all distances of sample 1604
# Calculating all distances of sample 1605
# Calculating all distances of sample 1606
# Calculating all distances of sample 1607
# Calculating all distances of sample 1608
# Calculating all distances of sample 1609
# Calculating all distances of sample 1610
# Calculating all distances of sample 1611
# Calculating all distances of sample 1612
# Calculating all distances of sample 1613
# Calculating all distances of sample 1614
# Calculating all distances of sample 1615
# Calculating all distances of sample 1616
# Calculating all distances of sample 1617
# Calculating all distances of sample 1618
# Calculating all distances of sample 1619
# Calculating all distances of sample 1620
# Calculating all distances of sample 1621
# Calculating all distances of sample 1622
# Calculating all distances of sample 1623
# Calculating all distances of sample 1624
# Calculating all distances of sample 1625
# Calculating all distances of sample 1626
# Calculating all distances of sample 1627
# Calculating all distances of sample 1628
# Calculating all distances of sample 1629
# Calculating all distances of sample 1630
# Calculating all distances of sample 1631
# Calculating all distances of sample 1632
# Calculating all distances of sample 1633
# Calculating all distances of sample 1634
# Calculating all distances of sample 1635
# Calculating all distances of sample 1636
# Calculating all distances of sample 1637
# Calculating all distances of sample 1638
# Calculating all distances of sample 1639
# Calculating all distances of sample 1640
# Calculating all distances of sample 1641
# Calculating all distances of sample 1642
# Calculating all distances of sample 1643
# Calculating all distances of sample 1644
# Calculating all distances of sample 1645
# Calculating all distances of sample 1646
# Calculating all distances of sample 1647
# Calculating all distances of sample 1648
# Calculating all distances of sample 1649
# Calculating all distances of sample 1650
# Calculating all distances of sample 1651
# Calculating all distances of sample 1652
# Calculating all distances of sample 1653
# Calculating all distances of sample 1654
# Calculating all distances of sample 1655
# Calculating all distances of sample 1656
# Calculating all distances of sample 1657
# Calculating all distances of sample 1658
# Calculating all distances of sample 1659
# Calculating all distances of sample 1660
# Calculating all distances of sample 1661
# Calculating all distances of sample 1662
# Calculating all distances of sample 1663
# Calculating all distances of sample 1664
# Calculating all distances of sample 1665
# Calculating all distances of sample 1666
# Calculating all distances of sample 1667
# Calculating all distances of sample 1668
# Calculating all distances of sample 1669
# Calculating all distances of sample 1670
# Calculating all distances of sample 1671
# Calculating all distances of sample 1672
# Calculating all distances of sample 1673
# Calculating all distances of sample 1674
# Calculating all distances of sample 1675
# Calculating all distances of sample 1676
# Calculating all distances of sample 1677
# Calculating all distances of sample 1678
# Calculating all distances of sample 1679
# Calculating all distances of sample 1680
# Calculating all distances of sample 1681
# Calculating all distances of sample 1682
# Calculating all distances of sample 1683
# Calculating all distances of sample 1684
# Calculating all distances of sample 1685
# Calculating all distances of sample 1686
# Calculating all distances of sample 1687
# Calculating all distances of sample 1688
# Calculating all distances of sample 1689
# Calculating all distances of sample 1690
# Calculating all distances of sample 1691
# Calculating all distances of sample 1692
# Calculating all distances of sample 1693
# Calculating all distances of sample 1694
# Calculating all distances of sample 1695
# Calculating all distances of sample 1696
# Calculating all distances of sample 1697
# Calculating all distances of sample 1698
# Calculating all distances of sample 1699
# Calculating all distances of sample 1700

# %%
len(W_dist)
# Out:
# 500

# %%
W_dist = json.load(open('/content/distances1200-1700.json'))

# %%
# for i in range(len(W_dist)):
#   W_dist[i][i+1000] = 1e9
w_dist = torch.Tensor(W_dist)

# %%
pred = w_dist.argmin(dim=1)

# %%
pred
# Out:
# tensor([3410, 3547, 3412, 3418, 3527, 3897, 3418, 3517, 3412, 3418, 3785, 3785,
#         3917, 3785, 3697, 3697, 3690, 3916, 3908, 3696, 3793, 3949, 3946, 3791,
#         3791, 3791, 3792, 3791, 3945, 3943, 3913, 3777, 3913, 3908, 3873, 3823,
#         3686, 3727, 3913, 3911, 3883, 3635, 3938, 3671, 3677, 3677, 3671, 3645,
#         3679, 3677, 3795, 3935, 3689, 3811, 3688, 3935, 3812, 3684, 3688, 3681,
#         3933, 3640, 3640, 3640, 3640, 3641, 3632, 3932, 3640, 3632, 3401, 3942,
#         3799, 3675, 3797, 3799, 3867, 3798, 3675, 3867, 3360, 3400, 3793, 3400,
#         3809, 3308, 3786, 3360, 3786, 3368, 3797, 3798, 3862, 3894, 3896, 3650,
#         3931, 3894, 3896, 3894, 3896, 3896, 3896, 3896, 3894, 3894, 3896, 3446,
#         3894, 3896, 3821, 3820, 3820, 3820, 3401, 3820, 3746, 3401, 3671, 3674,
#         3987, 4272, 4144, 4090, 4149, 4149, 4149, 4144, 4106, 4144, 4057,  120,
#         3962, 3962, 3962, 4250, 4250, 3962, 4256, 4253, 3979, 3979,  118,   34,
#          218, 3979, 3975, 4451, 3979, 3979, 3969, 3962, 3979, 4116, 3972, 3979,
#         3969, 3962, 3963, 3972, 4266, 4266, 4266, 4268, 4268, 4268, 4266, 4268,
#         4266, 4266, 4250, 4055, 4776, 4257, 4135, 4250, 4048, 4250, 4250, 4250,
#         3975, 4200, 4101, 4266, 4201, 4078, 4200, 4200, 4200, 4573,   75,   75,
#           75, 4026,    7,   75,   75,   75, 4790, 4694, 3989, 3989, 3989, 3989,
#         4095, 3989, 3989, 3989, 3989, 3989, 4256, 4256, 4256, 4256, 4256, 4257,
#         3961, 4256, 4270, 4151, 4155, 4260, 4064, 4101, 2453, 4152, 4152, 4073,
#         4152, 4264, 4483, 4570, 4335, 4570, 4578, 4320, 4320, 4577, 4574, 4483,
#         4305, 4461, 4305, 4305, 4305, 4606, 4305, 4451, 4305, 4548, 4416, 4416,
#         4398, 4487, 4492,  579, 4497, 4399, 4320, 4302, 4405, 4408, 4404, 4404,
#         4585, 4490, 4405, 4408, 4585, 4405, 4497,  483, 4585, 4476, 4337, 4507,
#         4570, 4415, 4585, 4340, 4298, 4448, 4509, 4444, 4593, 4509, 4299, 4299,
#         4586, 4293, 4404, 4546, 4605, 4548, 4546, 4294, 4605, 4546, 4607, 4605,
#         4412, 4450, 4501, 4155, 4416, 4415, 4417, 4414, 4501, 4474, 4479, 4613,
#         4479, 6286, 4479, 4550, 4582, 4523, 4550, 4550, 4479, 4478, 4479, 4444,
#         4479, 4479, 4478, 4501, 4478, 4563, 4474, 4537, 4478, 4305, 4478, 4478,
#         4557, 4305, 4403, 4478, 4807, 4807, 4807, 4800, 4808, 4803, 4807, 4807,
#         4803, 4807, 4727, 4724, 4916, 4907, 4907, 4916, 4727, 5130, 4908, 4745,
#          143, 4709, 4655, 4635, 4709, 4635, 4710, 4636, 4710, 4777, 4794, 4777,
#         4777, 4777, 4777, 4777, 4636, 4779, 4777, 4779, 4927, 4928, 4661, 4926,
#         4760, 4650, 4927, 4927, 4638, 4927, 4705, 4702, 4709, 4700, 4707, 4700,
#         4700, 4700, 4779, 4705, 4626, 4626, 4921, 4626, 4921, 4921, 4626, 4626,
#         4626, 4626, 2082, 2082, 2082, 2082, 2082, 2082, 2082, 2082, 2082, 2082,
#         5104, 5112, 5112, 4640, 4640, 5110, 4648, 5112, 5112, 4648, 4960, 4745,
#         5110, 5110, 4763, 4767, 4916, 4998, 4916, 5110, 4744, 4650, 5070, 4627,
#         4622, 4623, 5070, 4622, 4626, 2919, 3183, 5015, 5236, 5239, 5142, 5236,
#         5015, 5160, 5236, 3183, 5130, 5124, 5262, 5279, 5128, 5099, 5278, 5278,
#         5129, 5136, 5146, 3162, 5142, 5140, 5140, 5147, 5234, 5071, 5141, 3242,
#         4953, 5263, 5264, 5112, 5266, 5106, 4955, 5104, 5134, 5102, 5001, 4967,
#         5001, 5266, 5234, 5001, 5001, 4955, 5266, 5266])

# %%
sum(y_train[pred]==y_test[1200:1700])
# Out:
# tensor(466)
