# %%
import torch
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
def OPW_w(x: torch.Tensor, y: torch.Tensor, a: torch.Tensor = None, b: torch.Tensor = None, std=1, verbose=0, lambda1=0.1, lambda2=10,
          tol=.5e-2, maxIter=20, p_norm='inf', metric='sqreuclidean'):
    assert y.size(1) == x.size(1), "The dimensions of instances in the input sequences must be the same!"
    N = x.size(0)
    M = y.size(0)
    col_x = torch.arange(1, N+1)/N
    col_x = col_x.view(N, 1)
    col_y = torch.arange(1, M+1)/M
    relative_pos = col_x-col_y

    l = torch.abs(relative_pos) / ((1/N**2 + 1/M**2)**0.5)
    P = torch.exp(-l**2/(2*std**2)) / (std*(2*np.pi)**0.5)

    S = lambda1 / (relative_pos**2 + 1)

    D = pdist2(x, y, metric=metric)

    K = P * torch.exp((S - D) / lambda2)

    if a is None:
        a = torch.ones(N, 1) / N

    if b is None:
        b = torch.ones(M, 1) / M

    ainvK = K / a   # [N, M]

    iter = 0
    u = torch.ones(N, 1) / N
    while iter < maxIter:
        u = 1. / torch.matmul(ainvK, (b / (torch.matmul(K.T, u))))
        
        iter += 1
        if iter % 20 == 1 or iter == maxIter:
            v = b / torch.matmul(K.T, u)    # [M, 1]
            u = 1 / torch.matmul(ainvK, v)  # [N, 1]

            criterion = torch.sum(torch.abs(v * torch.matmul(K.T, u) - b), dim=0)
            criterion = criterion.norm(p=float(p_norm))
            if abs(criterion) < tol:
                break

            iter += 1
            if verbose > 0:
                print(f"Iteration : {iter}, Criterion: {criterion}")

    U = K * D   # [N, M]
    
    dist = torch.sum(u * torch.matmul(U, v), dim=0)
    T = v.T * (u * K)
 
    return dist, T

# %%
def pdist2(X, Y, metric='sqreuclidean'):
    if metric.lower() == 'sqreuclidean':
        return distEucSqr(X, Y)
    elif metric.lower() == 'euclidean':
        return torch.sqrt(distEucSqr(X, Y))
    elif metric.lower() == 'L1':
        return distL1(X, Y)
    elif metric.lower() == 'cosine':
        return distCosine(X, Y)
    elif metric.lower() == 'emd':
        return distEmd(X, Y)
    elif metric.lower() == 'chisqr':
        return distChiSqr(X, Y)
    else:
        raise NotImplementedError(f'pdist - unknown metric: {metric}')


def distL1(x: torch.Tensor, y: torch.Tensor):
    return torch.abs(x.unsqueeze(1) - y).sum(dim=-1)


def distCosine(x: torch.Tensor, y: torch.Tensor, eps=1e-8):
    assert x.dtype == torch.float or y.dtype == torch.float, "Inputs must be of type float"
    cos = torch.nn.CosineSimilarity(dim=-1, eps=eps)
    return 1 - cos(x.unsqueeze(1), y)


def distEmd(x: torch.Tensor, y: torch.Tensor):
    x_cdf = torch.cumsum(x, dim=-1)
    y_cdf = torch.cumsum(y, dim=-1)

    return torch.abs(x_cdf.unsqueeze(1) - y_cdf).sum(dim=-1)


def distEucSqr(x: torch.Tensor, y: torch.Tensor):
    return torch.cdist(x, y, p=2)**2


def distChiSqr(x: torch.Tensor, y: torch.Tensor, eps=1e-10):
    a = x.unsqueeze(1) + y
    b = x.unsqueeze(1) - y
    return (b**2 / (a + eps)).sum(dim=-1) / 2

# %%
def get_utterances(path):
  X = []
  utterances = []
  count = 0
  with open(path, 'r') as f:
      length_X = len([line for line in f.read().splitlines()])
  with open(path, 'r') as f:
      for line in f.read().splitlines():
          count += 1
          frame = [-abs(float(i)) if i.startswith('-') else abs(float(i)) for i in line.split()]
          if len(frame) > 0:
            utterances.append(frame)
            if count == length_X:
              X.append(utterances)
          else:
            if len(utterances) > 0:
              X.append(utterances)
              utterances = []
          
  return X

# %%
X_train = get_utterances(path="/content/Train_Arabic_Digit.txt")
X_test = get_utterances(path="/content/Test_Arabic_Digit.txt")
print(f"Number of training sample: {len(X_train)}")
print(f"Number of testing sample: {len(X_test)}")
# Out:
# Number of training sample: 6600
# Number of testing sample: 2200

# %%
import torch
import numpy as np
import json 

n_class = torch.Tensor(torch.arange(0, 10)).view(10, 1)
y_train = n_class.expand_as(torch.empty((10, 660))).contiguous().view(6600)
y_test = n_class.expand_as(torch.empty((10, 220))).contiguous().view(2200)

# %%
with open('fe.json', 'w') as f:
    json.dump(3, f)

# %%
W_dist = []
for idx_X, X in enumerate(X_test):
    if idx_X < 700 and idx_X >= 200:
      print(f'Calculating all distances of sample {idx_X+1}')
      W_X = []
      for idx_Y, Y in enumerate(X_train):
          dist, minT = OPW_w(torch.Tensor(X), torch.Tensor(Y), verbose=0, lambda1=0.1, lambda2=10)
          W_X.append(dist.item())
      W_dist.append(W_X)

with open('/content/distances200-700.json', 'w') as f:
    json.dump(W_dist, f)
# Out:
# Calculating all distances of sample 201
# Calculating all distances of sample 202
# Calculating all distances of sample 203
# Calculating all distances of sample 204
# Calculating all distances of sample 205
# Calculating all distances of sample 206
# Calculating all distances of sample 207
# Calculating all distances of sample 208
# Calculating all distances of sample 209
# Calculating all distances of sample 210
# Calculating all distances of sample 211
# Calculating all distances of sample 212
# Calculating all distances of sample 213
# Calculating all distances of sample 214
# Calculating all distances of sample 215
# Calculating all distances of sample 216
# Calculating all distances of sample 217
# Calculating all distances of sample 218
# Calculating all distances of sample 219
# Calculating all distances of sample 220
# Calculating all distances of sample 221
# Calculating all distances of sample 222
# Calculating all distances of sample 223
# Calculating all distances of sample 224
# Calculating all distances of sample 225
# Calculating all distances of sample 226
# Calculating all distances of sample 227
# Calculating all distances of sample 228
# Calculating all distances of sample 229
# Calculating all distances of sample 230
# Calculating all distances of sample 231
# Calculating all distances of sample 232
# Calculating all distances of sample 233
# Calculating all distances of sample 234
# Calculating all distances of sample 235
# Calculating all distances of sample 236
# Calculating all distances of sample 237
# Calculating all distances of sample 238
# Calculating all distances of sample 239
# Calculating all distances of sample 240
# Calculating all distances of sample 241
# Calculating all distances of sample 242
# Calculating all distances of sample 243
# Calculating all distances of sample 244
# Calculating all distances of sample 245
# Calculating all distances of sample 246
# Calculating all distances of sample 247
# Calculating all distances of sample 248
# Calculating all distances of sample 249
# Calculating all distances of sample 250
# Calculating all distances of sample 251
# Calculating all distances of sample 252
# Calculating all distances of sample 253
# Calculating all distances of sample 254
# Calculating all distances of sample 255
# Calculating all distances of sample 256
# Calculating all distances of sample 257
# Calculating all distances of sample 258
# Calculating all distances of sample 259
# Calculating all distances of sample 260
# Calculating all distances of sample 261
# Calculating all distances of sample 262
# Calculating all distances of sample 263
# Calculating all distances of sample 264
# Calculating all distances of sample 265
# Calculating all distances of sample 266
# Calculating all distances of sample 267
# Calculating all distances of sample 268
# Calculating all distances of sample 269
# Calculating all distances of sample 270
# Calculating all distances of sample 271
# Calculating all distances of sample 272
# Calculating all distances of sample 273
# Calculating all distances of sample 274
# Calculating all distances of sample 275
# Calculating all distances of sample 276
# Calculating all distances of sample 277
# Calculating all distances of sample 278
# Calculating all distances of sample 279
# Calculating all distances of sample 280
# Calculating all distances of sample 281
# Calculating all distances of sample 282
# Calculating all distances of sample 283
# Calculating all distances of sample 284
# Calculating all distances of sample 285
# Calculating all distances of sample 286
# Calculating all distances of sample 287
# Calculating all distances of sample 288
# Calculating all distances of sample 289
# Calculating all distances of sample 290
# Calculating all distances of sample 291
# Calculating all distances of sample 292
# Calculating all distances of sample 293
# Calculating all distances of sample 294
# Calculating all distances of sample 295
# Calculating all distances of sample 296
# Calculating all distances of sample 297
# Calculating all distances of sample 298
# Calculating all distances of sample 299
# Calculating all distances of sample 300
# Calculating all distances of sample 301
# Calculating all distances of sample 302
# Calculating all distances of sample 303
# Calculating all distances of sample 304
# Calculating all distances of sample 305
# Calculating all distances of sample 306
# Calculating all distances of sample 307
# Calculating all distances of sample 308
# Calculating all distances of sample 309
# Calculating all distances of sample 310
# Calculating all distances of sample 311
# Calculating all distances of sample 312
# Calculating all distances of sample 313
# Calculating all distances of sample 314
# Calculating all distances of sample 315
# Calculating all distances of sample 316
# Calculating all distances of sample 317
# Calculating all distances of sample 318
# Calculating all distances of sample 319
# Calculating all distances of sample 320
# Calculating all distances of sample 321
# Calculating all distances of sample 322
# Calculating all distances of sample 323
# Calculating all distances of sample 324
# Calculating all distances of sample 325
# Calculating all distances of sample 326
# Calculating all distances of sample 327
# Calculating all distances of sample 328
# Calculating all distances of sample 329
# Calculating all distances of sample 330
# Calculating all distances of sample 331
# Calculating all distances of sample 332
# Calculating all distances of sample 333
# Calculating all distances of sample 334
# Calculating all distances of sample 335
# Calculating all distances of sample 336
# Calculating all distances of sample 337
# Calculating all distances of sample 338
# Calculating all distances of sample 339
# Calculating all distances of sample 340
# Calculating all distances of sample 341
# Calculating all distances of sample 342
# Calculating all distances of sample 343
# Calculating all distances of sample 344
# Calculating all distances of sample 345
# Calculating all distances of sample 346
# Calculating all distances of sample 347
# Calculating all distances of sample 348
# Calculating all distances of sample 349
# Calculating all distances of sample 350
# Calculating all distances of sample 351
# Calculating all distances of sample 352
# Calculating all distances of sample 353
# Calculating all distances of sample 354
# Calculating all distances of sample 355
# Calculating all distances of sample 356
# Calculating all distances of sample 357
# Calculating all distances of sample 358
# Calculating all distances of sample 359
# Calculating all distances of sample 360
# Calculating all distances of sample 361
# Calculating all distances of sample 362
# Calculating all distances of sample 363
# Calculating all distances of sample 364
# Calculating all distances of sample 365
# Calculating all distances of sample 366
# Calculating all distances of sample 367
# Calculating all distances of sample 368
# Calculating all distances of sample 369
# Calculating all distances of sample 370
# Calculating all distances of sample 371
# Calculating all distances of sample 372
# Calculating all distances of sample 373
# Calculating all distances of sample 374
# Calculating all distances of sample 375
# Calculating all distances of sample 376
# Calculating all distances of sample 377
# Calculating all distances of sample 378
# Calculating all distances of sample 379
# Calculating all distances of sample 380
# Calculating all distances of sample 381
# Calculating all distances of sample 382
# Calculating all distances of sample 383
# Calculating all distances of sample 384
# Calculating all distances of sample 385
# Calculating all distances of sample 386
# Calculating all distances of sample 387
# Calculating all distances of sample 388
# Calculating all distances of sample 389
# Calculating all distances of sample 390
# Calculating all distances of sample 391
# Calculating all distances of sample 392
# Calculating all distances of sample 393
# Calculating all distances of sample 394
# Calculating all distances of sample 395
# Calculating all distances of sample 396
# Calculating all distances of sample 397
# Calculating all distances of sample 398
# Calculating all distances of sample 399
# Calculating all distances of sample 400
# Calculating all distances of sample 401
# Calculating all distances of sample 402
# Calculating all distances of sample 403
# Calculating all distances of sample 404
# Calculating all distances of sample 405
# Calculating all distances of sample 406
# Calculating all distances of sample 407
# Calculating all distances of sample 408
# Calculating all distances of sample 409
# Calculating all distances of sample 410
# Calculating all distances of sample 411
# Calculating all distances of sample 412
# Calculating all distances of sample 413
# Calculating all distances of sample 414
# Calculating all distances of sample 415
# Calculating all distances of sample 416
# Calculating all distances of sample 417
# Calculating all distances of sample 418
# Calculating all distances of sample 419
# Calculating all distances of sample 420
# Calculating all distances of sample 421
# Calculating all distances of sample 422
# Calculating all distances of sample 423
# Calculating all distances of sample 424
# Calculating all distances of sample 425
# Calculating all distances of sample 426
# Calculating all distances of sample 427
# Calculating all distances of sample 428
# Calculating all distances of sample 429
# Calculating all distances of sample 430
# Calculating all distances of sample 431
# Calculating all distances of sample 432
# Calculating all distances of sample 433
# Calculating all distances of sample 434
# Calculating all distances of sample 435
# Calculating all distances of sample 436
# Calculating all distances of sample 437
# Calculating all distances of sample 438
# Calculating all distances of sample 439
# Calculating all distances of sample 440
# Calculating all distances of sample 441
# Calculating all distances of sample 442
# Calculating all distances of sample 443
# Calculating all distances of sample 444
# Calculating all distances of sample 445
# Calculating all distances of sample 446
# Calculating all distances of sample 447
# Calculating all distances of sample 448
# Calculating all distances of sample 449
# Calculating all distances of sample 450
# Calculating all distances of sample 451
# Calculating all distances of sample 452
# Calculating all distances of sample 453
# Calculating all distances of sample 454
# Calculating all distances of sample 455
# Calculating all distances of sample 456
# Calculating all distances of sample 457
# Calculating all distances of sample 458
# Calculating all distances of sample 459
# Calculating all distances of sample 460
# Calculating all distances of sample 461
# Calculating all distances of sample 462
# Calculating all distances of sample 463
# Calculating all distances of sample 464
# Calculating all distances of sample 465
# Calculating all distances of sample 466
# Calculating all distances of sample 467
# Calculating all distances of sample 468
# Calculating all distances of sample 469
# Calculating all distances of sample 470
# Calculating all distances of sample 471
# Calculating all distances of sample 472
# Calculating all distances of sample 473
# Calculating all distances of sample 474
# Calculating all distances of sample 475
# Calculating all distances of sample 476
# Calculating all distances of sample 477
# Calculating all distances of sample 478
# Calculating all distances of sample 479
# Calculating all distances of sample 480
# Calculating all distances of sample 481
# Calculating all distances of sample 482
# Calculating all distances of sample 483
# Calculating all distances of sample 484
# Calculating all distances of sample 485
# Calculating all distances of sample 486
# Calculating all distances of sample 487
# Calculating all distances of sample 488
# Calculating all distances of sample 489
# Calculating all distances of sample 490
# Calculating all distances of sample 491
# Calculating all distances of sample 492
# Calculating all distances of sample 493
# Calculating all distances of sample 494
# Calculating all distances of sample 495
# Calculating all distances of sample 496
# Calculating all distances of sample 497
# Calculating all distances of sample 498
# Calculating all distances of sample 499
# Calculating all distances of sample 500
# Calculating all distances of sample 501
# Calculating all distances of sample 502
# Calculating all distances of sample 503
# Calculating all distances of sample 504
# Calculating all distances of sample 505
# Calculating all distances of sample 506
# Calculating all distances of sample 507
# Calculating all distances of sample 508
# Calculating all distances of sample 509
# Calculating all distances of sample 510
# Calculating all distances of sample 511
# Calculating all distances of sample 512
# Calculating all distances of sample 513
# Calculating all distances of sample 514
# Calculating all distances of sample 515
# Calculating all distances of sample 516
# Calculating all distances of sample 517
# Calculating all distances of sample 518
# Calculating all distances of sample 519
# Calculating all distances of sample 520
# Calculating all distances of sample 521
# Calculating all distances of sample 522
# Calculating all distances of sample 523
# Calculating all distances of sample 524
# Calculating all distances of sample 525
# Calculating all distances of sample 526
# Calculating all distances of sample 527
# Calculating all distances of sample 528
# Calculating all distances of sample 529
# Calculating all distances of sample 530
# Calculating all distances of sample 531
# Calculating all distances of sample 532
# Calculating all distances of sample 533
# Calculating all distances of sample 534
# Calculating all distances of sample 535
# Calculating all distances of sample 536
# Calculating all distances of sample 537
# Calculating all distances of sample 538
# Calculating all distances of sample 539
# Calculating all distances of sample 540
# Calculating all distances of sample 541
# Calculating all distances of sample 542
# Calculating all distances of sample 543
# Calculating all distances of sample 544
# Calculating all distances of sample 545
# Calculating all distances of sample 546
# Calculating all distances of sample 547
# Calculating all distances of sample 548
# Calculating all distances of sample 549
# Calculating all distances of sample 550
# Calculating all distances of sample 551
# Calculating all distances of sample 552
# Calculating all distances of sample 553
# Calculating all distances of sample 554
# Calculating all distances of sample 555
# Calculating all distances of sample 556
# Calculating all distances of sample 557
# Calculating all distances of sample 558
# Calculating all distances of sample 559
# Calculating all distances of sample 560
# Calculating all distances of sample 561
# Calculating all distances of sample 562
# Calculating all distances of sample 563
# Calculating all distances of sample 564
# Calculating all distances of sample 565
# Calculating all distances of sample 566
# Calculating all distances of sample 567
# Calculating all distances of sample 568
# Calculating all distances of sample 569
# Calculating all distances of sample 570
# Calculating all distances of sample 571
# Calculating all distances of sample 572
# Calculating all distances of sample 573
# Calculating all distances of sample 574
# Calculating all distances of sample 575
# Calculating all distances of sample 576
# Calculating all distances of sample 577
# Calculating all distances of sample 578
# Calculating all distances of sample 579
# Calculating all distances of sample 580
# Calculating all distances of sample 581
# Calculating all distances of sample 582
# Calculating all distances of sample 583
# Calculating all distances of sample 584
# Calculating all distances of sample 585
# Calculating all distances of sample 586
# Calculating all distances of sample 587
# Calculating all distances of sample 588
# Calculating all distances of sample 589
# Calculating all distances of sample 590
# Calculating all distances of sample 591
# Calculating all distances of sample 592
# Calculating all distances of sample 593
# Calculating all distances of sample 594
# Calculating all distances of sample 595
# Calculating all distances of sample 596
# Calculating all distances of sample 597
# Calculating all distances of sample 598
# Calculating all distances of sample 599
# Calculating all distances of sample 600
# Calculating all distances of sample 601
# Calculating all distances of sample 602
# Calculating all distances of sample 603
# Calculating all distances of sample 604
# Calculating all distances of sample 605
# Calculating all distances of sample 606
# Calculating all distances of sample 607
# Calculating all distances of sample 608
# Calculating all distances of sample 609
# Calculating all distances of sample 610
# Calculating all distances of sample 611
# Calculating all distances of sample 612
# Calculating all distances of sample 613
# Calculating all distances of sample 614
# Calculating all distances of sample 615
# Calculating all distances of sample 616
# Calculating all distances of sample 617
# Calculating all distances of sample 618
# Calculating all distances of sample 619
# Calculating all distances of sample 620
# Calculating all distances of sample 621
# Calculating all distances of sample 622
# Calculating all distances of sample 623
# Calculating all distances of sample 624
# Calculating all distances of sample 625
# Calculating all distances of sample 626
# Calculating all distances of sample 627
# Calculating all distances of sample 628
# Calculating all distances of sample 629
# Calculating all distances of sample 630
# Calculating all distances of sample 631
# Calculating all distances of sample 632
# Calculating all distances of sample 633
# Calculating all distances of sample 634
# Calculating all distances of sample 635
# Calculating all distances of sample 636
# Calculating all distances of sample 637
# Calculating all distances of sample 638
# Calculating all distances of sample 639
# Calculating all distances of sample 640
# Calculating all distances of sample 641
# Calculating all distances of sample 642
# Calculating all distances of sample 643
# Calculating all distances of sample 644
# Calculating all distances of sample 645
# Calculating all distances of sample 646
# Calculating all distances of sample 647
# Calculating all distances of sample 648
# Calculating all distances of sample 649
# Calculating all distances of sample 650
# Calculating all distances of sample 651
# Calculating all distances of sample 652
# Calculating all distances of sample 653
# Calculating all distances of sample 654
# Calculating all distances of sample 655
# Calculating all distances of sample 656
# Calculating all distances of sample 657
# Calculating all distances of sample 658
# Calculating all distances of sample 659
# Calculating all distances of sample 660
# Calculating all distances of sample 661
# Calculating all distances of sample 662
# Calculating all distances of sample 663
# Calculating all distances of sample 664
# Calculating all distances of sample 665
# Calculating all distances of sample 666
# Calculating all distances of sample 667
# Calculating all distances of sample 668
# Calculating all distances of sample 669
# Calculating all distances of sample 670
# Calculating all distances of sample 671
# Calculating all distances of sample 672
# Calculating all distances of sample 673
# Calculating all distances of sample 674
# Calculating all distances of sample 675
# Calculating all distances of sample 676
# Calculating all distances of sample 677
# Calculating all distances of sample 678
# Calculating all distances of sample 679
# Calculating all distances of sample 680
# Calculating all distances of sample 681
# Calculating all distances of sample 682
# Calculating all distances of sample 683
# Calculating all distances of sample 684
# Calculating all distances of sample 685
# Calculating all distances of sample 686
# Calculating all distances of sample 687
# Calculating all distances of sample 688
# Calculating all distances of sample 689
# Calculating all distances of sample 690
# Calculating all distances of sample 691
# Calculating all distances of sample 692
# Calculating all distances of sample 693
# Calculating all distances of sample 694
# Calculating all distances of sample 695
# Calculating all distances of sample 696
# Calculating all distances of sample 697
# Calculating all distances of sample 698
# Calculating all distances of sample 699
# Calculating all distances of sample 700

# %%
len(W_dist)
# Out:
# 500

# %%
W_dist = json.load(open('/content/distances200-700.json'))

# %%
# for i in range(len(W_dist)):
#   W_dist[i][i+1000] = 1e9
w_dist = torch.Tensor(W_dist)

# %%
pred = w_dist.argmin(dim=1)

# %%
pred
# Out:
# tensor([ 530,  470,   80,  479,  539,  550,  445,  488,  532,  444,  530,  533,
#          481,  481,  379,  484,  441,  484,  484,  531,  927,  845,  841,  841,
#          841,  841,  849, 1661,  684,  845,  780,  780,  780,  780,  780,  780,
#          889,  780,  780,  780,  671,  671,  695,  810,  695,  815,  671,  676,
#          695,  695,  665,  698,  665,  698,  788,  671,  722,  665,  665,  698,
#          969,  803,  803,  966,  803,  660,  796,  660,  660,  803,  823,  905,
#          748,  827,  722,  827,  827,  722,  827,  827,  885,  765,  899,  667,
#          883,  778,  669,  946,  946,  669,  750,  751,  751,  802,  759,  778,
#          800,  943,  759,  759,  969,  915,  770,  719,  852,  852,  969,  850,
#          850,  850,  711,  920,  920,  896,  889,  885,  889,  849,  849,  889,
#          780,  660,  780,  780,  716,  716,  780,  780,  716,  780, 1036, 1058,
#         1134, 1265, 1038, 1260, 1028, 1052, 1188, 1021, 1211, 1210, 1302, 1215,
#         1217, 1215, 1215, 1316, 1215, 1216, 1202, 1141, 1030, 1271, 1202, 1233,
#         1207, 1279, 1141, 1270, 1157, 1157, 1150, 1150, 1150, 1307, 1034, 1153,
#         1150, 1174, 1188, 1155, 1135, 1192,  725, 1188, 1307, 1058, 1154, 1202,
#         1252, 1157,  993, 1157, 1254, 1254, 1252, 1158, 1253, 1201, 1154, 1153,
#         1176, 1153, 1154, 1154, 1152, 1152, 1151, 1154, 1116, 1114, 1114, 1117,
#         1147, 1202, 1116, 1114, 1113, 1114, 1229, 1157, 1266, 1301, 1243, 1287,
#         1152, 1281, 1316, 1152, 1157, 1201, 1157, 1301, 1223, 1248, 1157, 1301,
#         1157, 1243, 1150, 1201, 1047, 1153, 1274, 1198, 1198, 1198, 1248, 1248,
#         1570, 1460, 1570, 1574, 1570, 1574, 1574, 1570, 1574, 1466, 1412, 1818,
#         1429, 1815, 1813, 1421, 1818, 1814, 1433, 1437, 1412, 1380, 1411, 1476,
#         1414, 1411, 1448, 1446, 1411, 1470, 1415, 1418, 1415, 1366, 1490, 1541,
#         1490, 1490, 1366, 1621, 1460, 1460, 1460, 1460, 1460, 1460, 1460, 1460,
#         1460, 1463, 1490, 1415, 1476, 1472, 1408, 1491, 1472, 1490, 1326, 1476,
#         1356, 1414, 1387, 1360, 1538, 1367, 1414, 1560, 1415, 1367, 1426, 1423,
#         1421, 1421, 1338, 1450, 1345, 1450, 1450, 1450, 1450, 1370, 1450, 1610,
#         1629, 1505, 1508, 1815, 1612, 1815, 1582, 1544, 1929, 1544, 6169, 6169,
#         1544, 1584, 1544, 1544, 1438, 1817, 6178, 1421, 1423, 1815, 1539, 1421,
#         1544, 6131, 1957, 1957, 1793, 1844, 1844, 1844, 1957, 1956, 1495, 1846,
#         1974, 1975, 1972, 1823, 1823, 1828, 1828, 1978, 1972, 1976, 1931, 1923,
#         1931, 1932, 1930, 1867, 1957, 1931, 1930, 1923, 1928, 1957, 1864, 1762,
#         1770, 1832, 1818, 1861, 1818, 1869, 1868, 1863, 1699, 1948, 1916, 1957,
#         1863, 1868, 1918, 1957, 1962, 1948, 1803, 1947, 1946, 1947, 1917, 1809,
#         1809, 1800, 1815, 1815, 1890, 1899, 1800, 1933, 1899, 1829, 1930, 1660,
#         1925, 1957, 1774, 1868, 1925, 1925, 1925, 1925, 1894, 1956, 1950, 1975,
#         1666, 1861, 1669, 1972, 1969, 1941, 1965, 1755, 1863, 1863, 1863, 1957,
#         1969, 1969, 1812, 1819, 1809, 1660, 1930, 1930, 1930, 1930, 1930, 1929,
#         1904, 1931, 1978, 1930, 2266, 2007, 2007, 2007, 2001, 2007, 2001, 2001,
#         2001, 2001, 2084, 2081, 2080, 2244, 2244, 2080, 2081, 2081, 2080, 2081,
#         1997, 2280, 1997, 1997, 1997, 1997, 1997, 1992, 1997, 1997, 2206, 2145,
#         5344, 2130, 5344, 5344, 2149, 2857, 2130, 5370])

# %%
sum(y_train[pred]==y_test[200:700])
# Out:
# tensor(490)
