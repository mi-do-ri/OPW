# %%
import torch
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
def OPW_w(x: torch.Tensor, y: torch.Tensor, a: torch.Tensor = None, b: torch.Tensor = None, std=1, verbose=0, lambda1=0.1, lambda2=10,
          tol=.5e-2, maxIter=20, p_norm='inf', metric='sqreuclidean'):
    assert y.size(1) == x.size(1), "The dimensions of instances in the input sequences must be the same!"
    N = x.size(0)
    M = y.size(0)
    col_x = torch.arange(1, N+1)/N
    col_x = col_x.view(N, 1)
    col_y = torch.arange(1, M+1)/M
    relative_pos = col_x-col_y

    l = torch.abs(relative_pos) / ((1/N**2 + 1/M**2)**0.5)
    P = torch.exp(-l**2/(2*std**2)) / (std*(2*np.pi)**0.5)

    S = lambda1 / (relative_pos**2 + 1)

    D = pdist2(x, y, metric=metric)

    K = P * torch.exp((S - D) / lambda2)

    if a is None:
        a = torch.ones(N, 1) / N

    if b is None:
        b = torch.ones(M, 1) / M

    ainvK = K / a   # [N, M]

    iter = 0
    u = torch.ones(N, 1) / N
    while iter < maxIter:
        u = 1. / torch.matmul(ainvK, (b / (torch.matmul(K.T, u))))
        
        iter += 1
        if iter % 20 == 1 or iter == maxIter:
            v = b / torch.matmul(K.T, u)    # [M, 1]
            u = 1 / torch.matmul(ainvK, v)  # [N, 1]

            criterion = torch.sum(torch.abs(v * torch.matmul(K.T, u) - b), dim=0)
            criterion = criterion.norm(p=float(p_norm))
            if abs(criterion) < tol:
                break

            iter += 1
            if verbose > 0:
                print(f"Iteration : {iter}, Criterion: {criterion}")

    U = K * D   # [N, M]
    
    dist = torch.sum(u * torch.matmul(U, v), dim=0)
    T = v.T * (u * K)
 
    return dist, T

# %%
def pdist2(X, Y, metric='sqreuclidean'):
    if metric.lower() == 'sqreuclidean':
        return distEucSqr(X, Y)
    elif metric.lower() == 'euclidean':
        return torch.sqrt(distEucSqr(X, Y))
    elif metric.lower() == 'L1':
        return distL1(X, Y)
    elif metric.lower() == 'cosine':
        return distCosine(X, Y)
    elif metric.lower() == 'emd':
        return distEmd(X, Y)
    elif metric.lower() == 'chisqr':
        return distChiSqr(X, Y)
    else:
        raise NotImplementedError(f'pdist - unknown metric: {metric}')


def distL1(x: torch.Tensor, y: torch.Tensor):
    return torch.abs(x.unsqueeze(1) - y).sum(dim=-1)


def distCosine(x: torch.Tensor, y: torch.Tensor, eps=1e-8):
    assert x.dtype == torch.float or y.dtype == torch.float, "Inputs must be of type float"
    cos = torch.nn.CosineSimilarity(dim=-1, eps=eps)
    return 1 - cos(x.unsqueeze(1), y)


def distEmd(x: torch.Tensor, y: torch.Tensor):
    x_cdf = torch.cumsum(x, dim=-1)
    y_cdf = torch.cumsum(y, dim=-1)

    return torch.abs(x_cdf.unsqueeze(1) - y_cdf).sum(dim=-1)


def distEucSqr(x: torch.Tensor, y: torch.Tensor):
    return torch.cdist(x, y, p=2)**2


def distChiSqr(x: torch.Tensor, y: torch.Tensor, eps=1e-10):
    a = x.unsqueeze(1) + y
    b = x.unsqueeze(1) - y
    return (b**2 / (a + eps)).sum(dim=-1) / 2

# %%
def get_utterances(path):
  X = []
  utterances = []
  count = 0
  with open(path, 'r') as f:
      length_X = len([line for line in f.read().splitlines()])
  with open(path, 'r') as f:
      for line in f.read().splitlines():
          count += 1
          frame = [-abs(float(i)) if i.startswith('-') else abs(float(i)) for i in line.split()]
          if len(frame) > 0:
            utterances.append(frame)
            if count == length_X:
              X.append(utterances)
          else:
            if len(utterances) > 0:
              X.append(utterances)
              utterances = []
          
  return X

# %%
X_train = get_utterances(path="/content/Train_Arabic_Digit.txt")
X_test = get_utterances(path="/content/Test_Arabic_Digit.txt")
print(f"Number of training sample: {len(X_train)}")
print(f"Number of testing sample: {len(X_test)}")
# Out:
# Number of training sample: 6600
# Number of testing sample: 2200

# %%
import torch
import numpy as np
import json 

n_class = torch.Tensor(torch.arange(0, 10)).view(10, 1)
y_train = n_class.expand_as(torch.empty((10, 660))).contiguous().view(6600)
y_test = n_class.expand_as(torch.empty((10, 220))).contiguous().view(2200)

# %%
with open('fe.json', 'w') as f:
    json.dump(3, f)

# %%
W_dist = []
for idx_X, X in enumerate(X_test):
    if idx_X < 200 and idx_X >= 0:
      print(f'Calculating all distances of sample {idx_X+1}')
      W_X = []
      for idx_Y, Y in enumerate(X_train):
          dist, minT = OPW_w(torch.Tensor(X), torch.Tensor(Y), verbose=0, lambda1=0.1, lambda2=10)
          W_X.append(dist.item())
      W_dist.append(W_X)

with open('/content/distances.json', 'w') as f:
    json.dump(W_dist, f)
# Out:
# Calculating all distances of sample 1
# Calculating all distances of sample 2
# Calculating all distances of sample 3
# Calculating all distances of sample 4
# Calculating all distances of sample 5
# Calculating all distances of sample 6
# Calculating all distances of sample 7
# Calculating all distances of sample 8
# Calculating all distances of sample 9
# Calculating all distances of sample 10
# Calculating all distances of sample 11
# Calculating all distances of sample 12
# Calculating all distances of sample 13
# Calculating all distances of sample 14
# Calculating all distances of sample 15
# Calculating all distances of sample 16
# Calculating all distances of sample 17
# Calculating all distances of sample 18
# Calculating all distances of sample 19
# Calculating all distances of sample 20
# Calculating all distances of sample 21
# Calculating all distances of sample 22
# Calculating all distances of sample 23
# Calculating all distances of sample 24
# Calculating all distances of sample 25
# Calculating all distances of sample 26
# Calculating all distances of sample 27
# Calculating all distances of sample 28
# Calculating all distances of sample 29
# Calculating all distances of sample 30
# Calculating all distances of sample 31
# Calculating all distances of sample 32
# Calculating all distances of sample 33
# Calculating all distances of sample 34
# Calculating all distances of sample 35
# Calculating all distances of sample 36
# Calculating all distances of sample 37
# Calculating all distances of sample 38
# Calculating all distances of sample 39
# Calculating all distances of sample 40
# Calculating all distances of sample 41
# Calculating all distances of sample 42
# Calculating all distances of sample 43
# Calculating all distances of sample 44
# Calculating all distances of sample 45
# Calculating all distances of sample 46
# Calculating all distances of sample 47
# Calculating all distances of sample 48
# Calculating all distances of sample 49
# Calculating all distances of sample 50
# Calculating all distances of sample 51
# Calculating all distances of sample 52
# Calculating all distances of sample 53
# Calculating all distances of sample 54
# Calculating all distances of sample 55
# Calculating all distances of sample 56
# Calculating all distances of sample 57
# Calculating all distances of sample 58
# Calculating all distances of sample 59
# Calculating all distances of sample 60
# Calculating all distances of sample 61
# Calculating all distances of sample 62
# Calculating all distances of sample 63
# Calculating all distances of sample 64
# Calculating all distances of sample 65
# Calculating all distances of sample 66
# Calculating all distances of sample 67
# Calculating all distances of sample 68
# Calculating all distances of sample 69
# Calculating all distances of sample 70
# Calculating all distances of sample 71
# Calculating all distances of sample 72
# Calculating all distances of sample 73
# Calculating all distances of sample 74
# Calculating all distances of sample 75
# Calculating all distances of sample 76
# Calculating all distances of sample 77
# Calculating all distances of sample 78
# Calculating all distances of sample 79
# Calculating all distances of sample 80
# Calculating all distances of sample 81
# Calculating all distances of sample 82
# Calculating all distances of sample 83
# Calculating all distances of sample 84
# Calculating all distances of sample 85
# Calculating all distances of sample 86
# Calculating all distances of sample 87
# Calculating all distances of sample 88
# Calculating all distances of sample 89
# Calculating all distances of sample 90
# Calculating all distances of sample 91
# Calculating all distances of sample 92
# Calculating all distances of sample 93
# Calculating all distances of sample 94
# Calculating all distances of sample 95
# Calculating all distances of sample 96
# Calculating all distances of sample 97
# Calculating all distances of sample 98
# Calculating all distances of sample 99
# Calculating all distances of sample 100
# Calculating all distances of sample 101
# Calculating all distances of sample 102
# Calculating all distances of sample 103
# Calculating all distances of sample 104
# Calculating all distances of sample 105
# Calculating all distances of sample 106
# Calculating all distances of sample 107
# Calculating all distances of sample 108
# Calculating all distances of sample 109
# Calculating all distances of sample 110
# Calculating all distances of sample 111
# Calculating all distances of sample 112
# Calculating all distances of sample 113
# Calculating all distances of sample 114
# Calculating all distances of sample 115
# Calculating all distances of sample 116
# Calculating all distances of sample 117
# Calculating all distances of sample 118
# Calculating all distances of sample 119
# Calculating all distances of sample 120
# Calculating all distances of sample 121
# Calculating all distances of sample 122
# Calculating all distances of sample 123
# Calculating all distances of sample 124
# Calculating all distances of sample 125
# Calculating all distances of sample 126
# Calculating all distances of sample 127
# Calculating all distances of sample 128
# Calculating all distances of sample 129
# Calculating all distances of sample 130
# Calculating all distances of sample 131
# Calculating all distances of sample 132
# Calculating all distances of sample 133
# Calculating all distances of sample 134
# Calculating all distances of sample 135
# Calculating all distances of sample 136
# Calculating all distances of sample 137
# Calculating all distances of sample 138
# Calculating all distances of sample 139
# Calculating all distances of sample 140
# Calculating all distances of sample 141
# Calculating all distances of sample 142
# Calculating all distances of sample 143
# Calculating all distances of sample 144
# Calculating all distances of sample 145
# Calculating all distances of sample 146
# Calculating all distances of sample 147
# Calculating all distances of sample 148
# Calculating all distances of sample 149
# Calculating all distances of sample 150
# Calculating all distances of sample 151
# Calculating all distances of sample 152
# Calculating all distances of sample 153
# Calculating all distances of sample 154
# Calculating all distances of sample 155
# Calculating all distances of sample 156
# Calculating all distances of sample 157
# Calculating all distances of sample 158
# Calculating all distances of sample 159
# Calculating all distances of sample 160
# Calculating all distances of sample 161
# Calculating all distances of sample 162
# Calculating all distances of sample 163
# Calculating all distances of sample 164
# Calculating all distances of sample 165
# Calculating all distances of sample 166
# Calculating all distances of sample 167
# Calculating all distances of sample 168
# Calculating all distances of sample 169
# Calculating all distances of sample 170
# Calculating all distances of sample 171
# Calculating all distances of sample 172
# Calculating all distances of sample 173
# Calculating all distances of sample 174
# Calculating all distances of sample 175
# Calculating all distances of sample 176
# Calculating all distances of sample 177
# Calculating all distances of sample 178
# Calculating all distances of sample 179
# Calculating all distances of sample 180
# Calculating all distances of sample 181
# Calculating all distances of sample 182
# Calculating all distances of sample 183
# Calculating all distances of sample 184
# Calculating all distances of sample 185
# Calculating all distances of sample 186
# Calculating all distances of sample 187
# Calculating all distances of sample 188
# Calculating all distances of sample 189
# Calculating all distances of sample 190
# Calculating all distances of sample 191
# Calculating all distances of sample 192
# Calculating all distances of sample 193
# Calculating all distances of sample 194
# Calculating all distances of sample 195
# Calculating all distances of sample 196
# Calculating all distances of sample 197
# Calculating all distances of sample 198
# Calculating all distances of sample 199
# Calculating all distances of sample 200

# %%
len(W_dist)
# Out:
# 200

# %%
W_dist = json.load(open('/content/distances.json'))

# %%
# for i in range(len(W_dist)):
#   W_dist[i][i+1000] = 1e9
w_dist = torch.Tensor(W_dist)

# %%
pred = w_dist.argmin(dim=1)

# %%
pred
# Out:
# tensor([  23,   23,  280,  280,  136, 4906,   24,  136, 4901, 4906,   90,   90,
#           90,  602,  296,   90,  561,   90,   90,   25,   30,   32,   17,   39,
#          153, 2130,  174,   35,   17,   34,  200,   11,  219,  126,   10,  236,
#           34,   32,  219,  219, 4714, 4783, 4714, 4714, 4620, 4714, 4714, 4783,
#         4716, 4660,   95,   88,  157,   88,   85,   85,   80,   95,   80,   88,
#          188,  234,  309,  220,  169,    7,  290,    7,    7,  295,   21,   12,
#          118,   11,  132,  307,  307,  307,  307,  106,    0,   14,   95,   22,
#           95,  223,  290,    7,   80,  290,   30,   30,  231,   30,   30,  270,
#          270, 4699, 4699,  270,  104,  297,  297,  186,  186,    7,    7,    9,
#         4896,   78,  616,  464,  619,  377,  547,  369,  524,  377,  360, 4578,
#          565,  604,  551,  606,  550,  499,  606,  606,  606,  504,  488,  451,
#          539,  520,  515,  451,  549,  533,  521,  519,  538,  549,  513,  464,
#          464,   65,  195,  444,  488,  470,   39,   38,  533,  527,  533,  534,
#          531,  629,  481,  606,  628,  333,  387,  388,  389,  388,  387,  487,
#          579,  519,  562,  445,  488,  488,  449,  523,  449,  445,  444,  445,
#          602,  492,  606,  487,  531,  481,  647,  492,  608,  532,   25,  503,
#           25,  479,  531,  495,  588,  331,  580,  594])

# %%
sum(y_train[pred]==y_test[0:200])
# Out:
# tensor(182)
